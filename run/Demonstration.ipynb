# %%
# !python -V
# Out:
# Python 3.7.16

# %% [markdown]
# #Train Model

# %%
# %cd ../
# !pip install -e .
# %cd run
# Out:
# /home/royhe62/Documents/Dockers/cypress/iCypressParallel
# Obtaining file:///home/royhe62/Documents/Dockers/cypress/iCypressParallel
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: yacs in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (0.1.8)
# Requirement already satisfied: tensorboardx in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (2.6.2.2)
# Requirement already satisfied: torch in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (1.8.0+cu101)
# Requirement already satisfied: torch-geometric in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (2.2.0)
# Requirement already satisfied: networkx in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (2.6.3)
# Requirement already satisfied: numpy in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (1.21.6)
# Requirement already satisfied: deepsnap in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (0.2.1)
# Requirement already satisfied: ogb in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (1.3.6)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (1.0.2)
# Requirement already satisfied: tqdm>=4.29.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (4.66.1)
# Requirement already satisfied: pandas>=0.24.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (1.3.5)
# Requirement already satisfied: six>=1.12.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (2.0.7)
# Requirement already satisfied: outdated>=0.2.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (0.2.2)
# Requirement already satisfied: typing-extensions in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch->graphgym==0.4.0) (4.7.1)
# Requirement already satisfied: protobuf>=3.20 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from tensorboardx->graphgym==0.4.0) (4.24.4)
# Requirement already satisfied: packaging in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from tensorboardx->graphgym==0.4.0) (23.2)
# Requirement already satisfied: requests in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch-geometric->graphgym==0.4.0) (2.31.0)
# Requirement already satisfied: scipy in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch-geometric->graphgym==0.4.0) (1.7.3)
# Requirement already satisfied: jinja2 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch-geometric->graphgym==0.4.0) (3.1.3)
# Requirement already satisfied: psutil>=5.8.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch-geometric->graphgym==0.4.0) (5.9.7)
# Requirement already satisfied: pyparsing in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch-geometric->graphgym==0.4.0) (3.1.1)
# Requirement already satisfied: PyYAML in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from yacs->graphgym==0.4.0) (6.0.1)
# Requirement already satisfied: littleutils in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from outdated>=0.2.0->ogb->graphgym==0.4.0) (0.2.2)
# Requirement already satisfied: setuptools>=44 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from outdated>=0.2.0->ogb->graphgym==0.4.0) (65.6.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from pandas>=0.24.0->ogb->graphgym==0.4.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from pandas>=0.24.0->ogb->graphgym==0.4.0) (2023.3.post1)
# Requirement already satisfied: joblib>=0.11 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from scikit-learn>=0.20.0->ogb->graphgym==0.4.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from scikit-learn>=0.20.0->ogb->graphgym==0.4.0) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from jinja2->torch-geometric->graphgym==0.4.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from requests->torch-geometric->graphgym==0.4.0) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from requests->torch-geometric->graphgym==0.4.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from requests->torch-geometric->graphgym==0.4.0) (3.6)
# Installing collected packages: graphgym
#   Attempting uninstall: graphgym
#     Found existing installation: graphgym 0.4.0
#     Uninstalling graphgym-0.4.0:
#       Successfully uninstalled graphgym-0.4.0
#   Running setup.py develop for graphgym
# Successfully installed graphgym-0.4.0
# /home/royhe62/Documents/Dockers/cypress/iCypressParallel/run

# %%
# !bash custom.sh GSE40240_eset GSE40240_patients CCL3 False NULL NULL True
# Out:
# CCL3_GSE40240_eset
# Processing...
# CCL3_GSE40240_eset
# Done!
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/torch_geometric/graphgym/imports.py:14: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/torch_geometric/graphgym/logger.py:23: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "
# WARNING:root:dataset.transductive changed to False for graph task.
# Load: 0.04321s, Before split: 0.0003707s, Split: 9.966e-05s, After split: 0.001332s
# GNN(
#   (preprocess): Preprocess(
#     node_feature: dim_out=833
#     Total: dim_out=833
#   )
#   (pre_mp): GeneralMultiLayer(
#     (Layer_0): GeneralLayer(
#       (layer): Linear(
#         (model): Linear(in_features=833, out_features=137, bias=False)
#       )
#       (post_layer): Sequential(
#         (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): PReLU(num_parameters=1)
#       )
#     )
#     (Layer_1): GeneralLayer(
#       (layer): Linear(
#         (model): Linear(in_features=137, out_features=137, bias=False)
#       )
#       (post_layer): Sequential(
#         (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): PReLU(num_parameters=1)
#       )
#     )
#   )
#   (mp): GNNSkipStage(
#     (block0): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block1): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block2): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block3): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block4): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block5): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#   )
#   (post_mp): GNNGraphHead(
#     (layer_post_mp): MLP(
#       (model): Sequential(
#         (0): GeneralMultiLayer(
#           (Layer_0): GeneralLayer(
#             (layer): Linear(
#               (model): Linear(in_features=137, out_features=137, bias=False)
#             )
#             (post_layer): Sequential(
#               (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): PReLU(num_parameters=1)
#             )
#           )
#         )
#         (1): Linear(
#           (model): Linear(in_features=137, out_features=1, bias=True)
#         )
#       )
#     )
#   )
# )
# bn:
#   eps: 1e-05
#   mom: 0.1
# cfg_dest: config.yaml
# custom_metrics: []
# dataset:
#   augment_feature: []
#   augment_feature_dims: []
#   augment_feature_repr: position
#   augment_label:
#   augment_label_dims: 0
#   cache_load: False
#   cache_save: False
#   dir: ./datasets
#   edge_dim: 128
#   edge_encoder: False
#   edge_encoder_bn: True
#   edge_encoder_name: Bond
#   edge_message_ratio: 0.8
#   edge_negative_sampling_ratio: 1.0
#   edge_train_mode: all
#   encoder: True
#   encoder_bn: True
#   encoder_dim: 128
#   encoder_name: db
#   format: PyG
#   label_column: none
#   label_table: none
#   location: local
#   name: Custom,CCL3_GSE40240_eset,,
#   node_encoder: False
#   node_encoder_bn: True
#   node_encoder_name: Atom
#   remove_feature: False
#   resample_disjoint: False
#   resample_negative: False
#   shuffle_split: True
#   split: [0.8, 0.2]
#   split_mode: random
#   task: graph
#   task_type: classification
#   to_undirected: False
#   transductive: False
#   transform: none
#   tu_simple: True
# device: cpu
# example_arg: example
# example_group:
#   example_arg: example
# gnn:
#   act: prelu
#   agg: add
#   att_final_linear: False
#   att_final_linear_bn: False
#   att_heads: 1
#   batchnorm: True
#   clear_feature: True
#   dim_inner: 137
#   dropout: 0.0
#   flow: source_to_target
#   head: graph
#   keep_edge: 0.5
#   l2norm: True
#   layer_type: generalconv
#   layers_mp: 6
#   layers_post_mp: 2
#   layers_pre_mp: 2
#   msg_direction: single
#   normalize_adj: False
#   self_msg: concat
#   skip_every: 1
#   stage_type: skipsum
# gpu_mem: False
# mem:
#   inplace: False
# metric_agg: argmax
# metric_best: auto
# model:
#   edge_decoding: dot
#   graph_pooling: add
#   loss_fun: cross_entropy
#   match_upper: True
#   size_average: mean
#   thresh: 0.5
#   type: gnn
# num_threads: 6
# num_workers: 0
# optim:
#   base_lr: 0.01
#   lr_decay: 0.1
#   max_epoch: 400
#   momentum: 0.9
#   optimizer: adam
#   scheduler: cos
#   steps: [30, 60, 90]
#   weight_decay: 0.0005
# out_dir: results/CCL3_GSE40240_eset
# print: both
# round: 4
# run_dir: results/CCL3_GSE40240_eset/0
# seed: 1
# share:
#   dim_in: 833
#   dim_out: 1
#   num_splits: 2
# tensorboard_agg: True
# tensorboard_each_run: False
# train:
#   auto_resume: False
#   batch_size: 80
#   ckpt_clean: True
#   ckpt_period: 100
#   enable_ckpt: True
#   epoch_resume: -1
#   eval_period: 20
#   iter_per_epoch: 32
#   mode: standard
#   neighbor_sizes: [20, 15, 10, 5]
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
#   skip_train_eval: False
#   walk_length: 4
# val:
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
# view_emb: False
# Num parameters: 379492
# Start from epoch 0
# train: {'epoch': 0, 'eta': 44.1146, 'loss': 0.8422, 'lr': 0.01, 'params': 379492, 'time_iter': 0.1106, 'accuracy': 0.5909, 'precision': 0.4545, 'recall': 0.625, 'f1': 0.5263, 'auc': 0.5893}
# val: {'epoch': 0, 'loss': 0.033, 'lr': 0, 'params': 379492, 'time_iter': 0.0183, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 0.0}
# train: {'epoch': 1, 'eta': 43.3894, 'loss': 1.2253, 'lr': 0.01, 'params': 379492, 'time_iter': 0.1075, 'accuracy': 0.5, 'precision': 0.3636, 'recall': 0.5, 'f1': 0.4211, 'auc': 0.5804}
# train: {'epoch': 2, 'eta': 40.0808, 'loss': 0.7413, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0848, 'accuracy': 0.8182, 'precision': 0.7, 'recall': 0.875, 'f1': 0.7778, 'auc': 0.8393}
# train: {'epoch': 3, 'eta': 38.6719, 'loss': 0.6653, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0877, 'accuracy': 0.7727, 'precision': 0.6667, 'recall': 0.75, 'f1': 0.7059, 'auc': 0.8929}
# train: {'epoch': 4, 'eta': 40.1077, 'loss': 0.2035, 'lr': 0.01, 'params': 379492, 'time_iter': 0.1171, 'accuracy': 0.9545, 'precision': 0.8889, 'recall': 1.0, 'f1': 0.9412, 'auc': 0.9821}
# train: {'epoch': 5, 'eta': 39.2953, 'loss': 0.2097, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0907, 'accuracy': 0.8636, 'precision': 0.7273, 'recall': 1.0, 'f1': 0.8421, 'auc': 1.0}
# train: {'epoch': 6, 'eta': 38.4774, 'loss': 0.0449, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0869, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 7, 'eta': 37.5121, 'loss': 0.0372, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0802, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 8, 'eta': 37.1422, 'loss': 0.0202, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0894, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 9, 'eta': 36.7925, 'loss': 0.0089, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0885, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 10, 'eta': 36.4439, 'loss': 0.0061, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0871, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 11, 'eta': 36.1874, 'loss': 0.0054, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0886, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 12, 'eta': 36.2793, 'loss': 0.0045, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0995, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 13, 'eta': 35.9247, 'loss': 0.0035, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0843, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 14, 'eta': 35.5898, 'loss': 0.0028, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0836, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 15, 'eta': 35.3733, 'loss': 0.0025, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0873, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 16, 'eta': 35.3104, 'loss': 0.0023, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0934, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 17, 'eta': 35.0986, 'loss': 0.0022, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0866, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 18, 'eta': 35.0341, 'loss': 0.002, 'lr': 0.01, 'params': 379492, 'time_iter': 0.0932, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 19, 'eta': 34.8129, 'loss': 0.0018, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.0852, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# val: {'epoch': 19, 'loss': 0.0128, 'lr': 0, 'params': 379492, 'time_iter': 0.0248, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 0.0}
# train: {'epoch': 20, 'eta': 34.5845, 'loss': 0.0016, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.084, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 21, 'eta': 34.4645, 'loss': 0.0014, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.0896, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 22, 'eta': 34.2762, 'loss': 0.0013, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.0852, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 23, 'eta': 34.1401, 'loss': 0.0012, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.088, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 24, 'eta': 33.9596, 'loss': 0.0011, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.0848, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 25, 'eta': 33.7475, 'loss': 0.001, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.0821, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 26, 'eta': 33.7357, 'loss': 0.0009, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.0959, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 27, 'eta': 33.5281, 'loss': 0.0009, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.0816, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 28, 'eta': 33.4304, 'loss': 0.0008, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.0895, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 29, 'eta': 33.3402, 'loss': 0.0008, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.0901, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 30, 'eta': 33.1867, 'loss': 0.0008, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.0848, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 31, 'eta': 33.0322, 'loss': 0.0007, 'lr': 0.0099, 'params': 379492, 'time_iter': 0.0843, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 32, 'eta': 32.8656, 'loss': 0.0007, 'lr': 0.0098, 'params': 379492, 'time_iter': 0.0829, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 33, 'eta': 32.7942, 'loss': 0.0007, 'lr': 0.0098, 'params': 379492, 'time_iter': 0.0912, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 34, 'eta': 32.686, 'loss': 0.0006, 'lr': 0.0098, 'params': 379492, 'time_iter': 0.0878, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 35, 'eta': 32.5707, 'loss': 0.0006, 'lr': 0.0098, 'params': 379492, 'time_iter': 0.087, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 36, 'eta': 32.4686, 'loss': 0.0006, 'lr': 0.0098, 'params': 379492, 'time_iter': 0.0882, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 37, 'eta': 32.35, 'loss': 0.0006, 'lr': 0.0098, 'params': 379492, 'time_iter': 0.0864, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 38, 'eta': 32.2931, 'loss': 0.0006, 'lr': 0.0098, 'params': 379492, 'time_iter': 0.0929, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 39, 'eta': 32.1734, 'loss': 0.0006, 'lr': 0.0098, 'params': 379492, 'time_iter': 0.0861, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# val: {'epoch': 39, 'loss': 5.7535, 'lr': 0, 'params': 379492, 'time_iter': 0.0117, 'accuracy': 0.1667, 'precision': 1.0, 'recall': 0.1667, 'f1': 0.2857, 'auc': 0.0}
# train: {'epoch': 40, 'eta': 32.097, 'loss': 0.0006, 'lr': 0.0098, 'params': 379492, 'time_iter': 0.0909, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 41, 'eta': 31.9498, 'loss': 0.0006, 'lr': 0.0097, 'params': 379492, 'time_iter': 0.0826, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 42, 'eta': 31.8148, 'loss': 0.0006, 'lr': 0.0097, 'params': 379492, 'time_iter': 0.0837, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 43, 'eta': 31.66, 'loss': 0.0006, 'lr': 0.0097, 'params': 379492, 'time_iter': 0.081, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 44, 'eta': 31.5252, 'loss': 0.0006, 'lr': 0.0097, 'params': 379492, 'time_iter': 0.0831, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 45, 'eta': 31.4524, 'loss': 0.0005, 'lr': 0.0097, 'params': 379492, 'time_iter': 0.0909, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 46, 'eta': 31.33, 'loss': 0.0005, 'lr': 0.0097, 'params': 379492, 'time_iter': 0.0844, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 47, 'eta': 31.2185, 'loss': 0.0005, 'lr': 0.0097, 'params': 379492, 'time_iter': 0.0857, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 48, 'eta': 31.0825, 'loss': 0.0005, 'lr': 0.0096, 'params': 379492, 'time_iter': 0.0821, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 49, 'eta': 30.978, 'loss': 0.0005, 'lr': 0.0096, 'params': 379492, 'time_iter': 0.0863, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 50, 'eta': 30.8712, 'loss': 0.0005, 'lr': 0.0096, 'params': 379492, 'time_iter': 0.0858, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 51, 'eta': 30.7887, 'loss': 0.0005, 'lr': 0.0096, 'params': 379492, 'time_iter': 0.0894, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 52, 'eta': 30.6813, 'loss': 0.0005, 'lr': 0.0096, 'params': 379492, 'time_iter': 0.0856, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 53, 'eta': 30.5722, 'loss': 0.0005, 'lr': 0.0096, 'params': 379492, 'time_iter': 0.0852, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 54, 'eta': 30.4904, 'loss': 0.0005, 'lr': 0.0096, 'params': 379492, 'time_iter': 0.0894, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 55, 'eta': 30.3728, 'loss': 0.0005, 'lr': 0.0095, 'params': 379492, 'time_iter': 0.0836, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 56, 'eta': 30.2684, 'loss': 0.0005, 'lr': 0.0095, 'params': 379492, 'time_iter': 0.0856, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 57, 'eta': 30.2029, 'loss': 0.0005, 'lr': 0.0095, 'params': 379492, 'time_iter': 0.0921, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 58, 'eta': 30.086, 'loss': 0.0005, 'lr': 0.0095, 'params': 379492, 'time_iter': 0.0834, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 59, 'eta': 30.0096, 'loss': 0.0005, 'lr': 0.0095, 'params': 379492, 'time_iter': 0.0903, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 59, 'loss': 9.0662, 'lr': 0, 'params': 379492, 'time_iter': 0.017, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 60, 'eta': 29.9012, 'loss': 0.0005, 'lr': 0.0095, 'params': 379492, 'time_iter': 0.0846, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 61, 'eta': 29.8101, 'loss': 0.0005, 'lr': 0.0094, 'params': 379492, 'time_iter': 0.0877, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 62, 'eta': 29.7207, 'loss': 0.0004, 'lr': 0.0094, 'params': 379492, 'time_iter': 0.088, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 63, 'eta': 29.6265, 'loss': 0.0004, 'lr': 0.0094, 'params': 379492, 'time_iter': 0.0871, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 64, 'eta': 29.5223, 'loss': 0.0004, 'lr': 0.0094, 'params': 379492, 'time_iter': 0.0851, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 65, 'eta': 29.4674, 'loss': 0.0004, 'lr': 0.0094, 'params': 379492, 'time_iter': 0.0947, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 66, 'eta': 29.5649, 'loss': 0.0004, 'lr': 0.0093, 'params': 379492, 'time_iter': 0.1256, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 67, 'eta': 29.5327, 'loss': 0.0004, 'lr': 0.0093, 'params': 379492, 'time_iter': 0.1004, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 68, 'eta': 29.5319, 'loss': 0.0004, 'lr': 0.0093, 'params': 379492, 'time_iter': 0.1073, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 69, 'eta': 29.4382, 'loss': 0.0004, 'lr': 0.0093, 'params': 379492, 'time_iter': 0.0883, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 70, 'eta': 29.3485, 'loss': 0.0004, 'lr': 0.0093, 'params': 379492, 'time_iter': 0.0891, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 71, 'eta': 29.6625, 'loss': 0.0004, 'lr': 0.0092, 'params': 379492, 'time_iter': 0.1777, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 72, 'eta': 29.6894, 'loss': 0.0004, 'lr': 0.0092, 'params': 379492, 'time_iter': 0.1166, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 73, 'eta': 29.5842, 'loss': 0.0004, 'lr': 0.0092, 'params': 379492, 'time_iter': 0.0875, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 74, 'eta': 29.5111, 'loss': 0.0004, 'lr': 0.0092, 'params': 379492, 'time_iter': 0.0948, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 75, 'eta': 29.5514, 'loss': 0.0004, 'lr': 0.0092, 'params': 379492, 'time_iter': 0.1215, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 76, 'eta': 29.798, 'loss': 0.0004, 'lr': 0.0091, 'params': 379492, 'time_iter': 0.1718, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 77, 'eta': 30.2511, 'loss': 0.0004, 'lr': 0.0091, 'params': 379492, 'time_iter': 0.2244, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 78, 'eta': 30.4016, 'loss': 0.0004, 'lr': 0.0091, 'params': 379492, 'time_iter': 0.1541, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 79, 'eta': 30.42, 'loss': 0.0004, 'lr': 0.0091, 'params': 379492, 'time_iter': 0.123, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 79, 'loss': 9.2797, 'lr': 0, 'params': 379492, 'time_iter': 0.0211, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 80, 'eta': 30.4299, 'loss': 0.0004, 'lr': 0.009, 'params': 379492, 'time_iter': 0.1217, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 81, 'eta': 31.4461, 'loss': 0.0004, 'lr': 0.009, 'params': 379492, 'time_iter': 0.382, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 82, 'eta': 31.654, 'loss': 0.0004, 'lr': 0.009, 'params': 379492, 'time_iter': 0.1792, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 83, 'eta': 31.7177, 'loss': 0.0004, 'lr': 0.009, 'params': 379492, 'time_iter': 0.1433, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 84, 'eta': 31.9374, 'loss': 0.0004, 'lr': 0.009, 'params': 379492, 'time_iter': 0.1867, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 85, 'eta': 32.1688, 'loss': 0.0004, 'lr': 0.0089, 'params': 379492, 'time_iter': 0.1925, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 86, 'eta': 32.2495, 'loss': 0.0004, 'lr': 0.0089, 'params': 379492, 'time_iter': 0.1534, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 87, 'eta': 32.2463, 'loss': 0.0004, 'lr': 0.0089, 'params': 379492, 'time_iter': 0.1312, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 88, 'eta': 32.1389, 'loss': 0.0004, 'lr': 0.0089, 'params': 379492, 'time_iter': 0.1022, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 89, 'eta': 32.1126, 'loss': 0.0004, 'lr': 0.0088, 'params': 379492, 'time_iter': 0.1257, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 90, 'eta': 32.2234, 'loss': 0.0004, 'lr': 0.0088, 'params': 379492, 'time_iter': 0.1667, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 91, 'eta': 32.249, 'loss': 0.0004, 'lr': 0.0088, 'params': 379492, 'time_iter': 0.1431, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 92, 'eta': 32.1941, 'loss': 0.0004, 'lr': 0.0088, 'params': 379492, 'time_iter': 0.1198, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 93, 'eta': 32.2391, 'loss': 0.0004, 'lr': 0.0087, 'params': 379492, 'time_iter': 0.1509, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 94, 'eta': 32.3213, 'loss': 0.0004, 'lr': 0.0087, 'params': 379492, 'time_iter': 0.1638, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 95, 'eta': 32.2265, 'loss': 0.0004, 'lr': 0.0087, 'params': 379492, 'time_iter': 0.1095, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 96, 'eta': 32.0967, 'loss': 0.0004, 'lr': 0.0086, 'params': 379492, 'time_iter': 0.0984, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 97, 'eta': 32.1151, 'loss': 0.0004, 'lr': 0.0086, 'params': 379492, 'time_iter': 0.1463, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 98, 'eta': 32.0935, 'loss': 0.0004, 'lr': 0.0086, 'params': 379492, 'time_iter': 0.1342, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 99, 'eta': 32.1722, 'loss': 0.0004, 'lr': 0.0086, 'params': 379492, 'time_iter': 0.1684, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 99, 'loss': 9.0516, 'lr': 0, 'params': 379492, 'time_iter': 0.0317, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 100, 'eta': 32.1558, 'loss': 0.0004, 'lr': 0.0085, 'params': 379492, 'time_iter': 0.1379, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 101, 'eta': 32.4714, 'loss': 0.0004, 'lr': 0.0085, 'params': 379492, 'time_iter': 0.2524, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 102, 'eta': 32.5916, 'loss': 0.0004, 'lr': 0.0085, 'params': 379492, 'time_iter': 0.1884, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 103, 'eta': 32.5869, 'loss': 0.0004, 'lr': 0.0085, 'params': 379492, 'time_iter': 0.1466, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 104, 'eta': 32.4304, 'loss': 0.0004, 'lr': 0.0084, 'params': 379492, 'time_iter': 0.0936, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 105, 'eta': 32.3075, 'loss': 0.0004, 'lr': 0.0084, 'params': 379492, 'time_iter': 0.1052, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 106, 'eta': 32.3283, 'loss': 0.0004, 'lr': 0.0084, 'params': 379492, 'time_iter': 0.1576, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 107, 'eta': 32.5633, 'loss': 0.0004, 'lr': 0.0083, 'params': 379492, 'time_iter': 0.2381, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 108, 'eta': 32.535, 'loss': 0.0004, 'lr': 0.0083, 'params': 379492, 'time_iter': 0.1427, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 109, 'eta': 32.3952, 'loss': 0.0004, 'lr': 0.0083, 'params': 379492, 'time_iter': 0.1012, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 110, 'eta': 32.2262, 'loss': 0.0004, 'lr': 0.0082, 'params': 379492, 'time_iter': 0.0897, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 111, 'eta': 32.2714, 'loss': 0.0004, 'lr': 0.0082, 'params': 379492, 'time_iter': 0.1725, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 112, 'eta': 32.1458, 'loss': 0.0004, 'lr': 0.0082, 'params': 379492, 'time_iter': 0.1067, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 113, 'eta': 31.9847, 'loss': 0.0004, 'lr': 0.0082, 'params': 379492, 'time_iter': 0.0924, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 114, 'eta': 31.8791, 'loss': 0.0004, 'lr': 0.0081, 'params': 379492, 'time_iter': 0.1143, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 115, 'eta': 31.7894, 'loss': 0.0004, 'lr': 0.0081, 'params': 379492, 'time_iter': 0.1209, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 116, 'eta': 31.692, 'loss': 0.0004, 'lr': 0.0081, 'params': 379492, 'time_iter': 0.118, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 117, 'eta': 31.6186, 'loss': 0.0004, 'lr': 0.008, 'params': 379492, 'time_iter': 0.1281, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 118, 'eta': 31.5257, 'loss': 0.0004, 'lr': 0.008, 'params': 379492, 'time_iter': 0.1203, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 119, 'eta': 31.424, 'loss': 0.0004, 'lr': 0.008, 'params': 379492, 'time_iter': 0.1167, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 119, 'loss': 8.778, 'lr': 0, 'params': 379492, 'time_iter': 0.0208, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 120, 'eta': 31.328, 'loss': 0.0004, 'lr': 0.0079, 'params': 379492, 'time_iter': 0.1193, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 121, 'eta': 31.2136, 'loss': 0.0004, 'lr': 0.0079, 'params': 379492, 'time_iter': 0.1113, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 122, 'eta': 31.1105, 'loss': 0.0004, 'lr': 0.0079, 'params': 379492, 'time_iter': 0.1164, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 123, 'eta': 30.9939, 'loss': 0.0004, 'lr': 0.0078, 'params': 379492, 'time_iter': 0.1104, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 124, 'eta': 30.8783, 'loss': 0.0004, 'lr': 0.0078, 'params': 379492, 'time_iter': 0.1108, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 125, 'eta': 30.7099, 'loss': 0.0004, 'lr': 0.0078, 'params': 379492, 'time_iter': 0.0865, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 126, 'eta': 30.5447, 'loss': 0.0004, 'lr': 0.0077, 'params': 379492, 'time_iter': 0.0873, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 127, 'eta': 30.3996, 'loss': 0.0004, 'lr': 0.0077, 'params': 379492, 'time_iter': 0.0963, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 128, 'eta': 30.263, 'loss': 0.0004, 'lr': 0.0077, 'params': 379492, 'time_iter': 0.0999, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 129, 'eta': 30.2303, 'loss': 0.0004, 'lr': 0.0076, 'params': 379492, 'time_iter': 0.1497, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 130, 'eta': 30.1611, 'loss': 0.0004, 'lr': 0.0076, 'params': 379492, 'time_iter': 0.1328, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 131, 'eta': 30.0927, 'loss': 0.0004, 'lr': 0.0076, 'params': 379492, 'time_iter': 0.1337, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 132, 'eta': 30.1081, 'loss': 0.0003, 'lr': 0.0075, 'params': 379492, 'time_iter': 0.1759, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 133, 'eta': 30.1353, 'loss': 0.0003, 'lr': 0.0075, 'params': 379492, 'time_iter': 0.1833, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 134, 'eta': 30.0538, 'loss': 0.0003, 'lr': 0.0075, 'params': 379492, 'time_iter': 0.1295, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 135, 'eta': 29.9164, 'loss': 0.0003, 'lr': 0.0074, 'params': 379492, 'time_iter': 0.1011, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 136, 'eta': 29.7904, 'loss': 0.0003, 'lr': 0.0074, 'params': 379492, 'time_iter': 0.1067, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 137, 'eta': 29.6537, 'loss': 0.0003, 'lr': 0.0074, 'params': 379492, 'time_iter': 0.1009, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 138, 'eta': 29.5352, 'loss': 0.0003, 'lr': 0.0073, 'params': 379492, 'time_iter': 0.1103, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 139, 'eta': 29.4072, 'loss': 0.0003, 'lr': 0.0073, 'params': 379492, 'time_iter': 0.1052, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 139, 'loss': 8.542, 'lr': 0, 'params': 379492, 'time_iter': 0.0197, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 140, 'eta': 29.2746, 'loss': 0.0003, 'lr': 0.0073, 'params': 379492, 'time_iter': 0.1025, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 141, 'eta': 29.1478, 'loss': 0.0003, 'lr': 0.0072, 'params': 379492, 'time_iter': 0.1055, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 142, 'eta': 29.0274, 'loss': 0.0003, 'lr': 0.0072, 'params': 379492, 'time_iter': 0.1089, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 143, 'eta': 28.8962, 'loss': 0.0003, 'lr': 0.0072, 'params': 379492, 'time_iter': 0.1027, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 144, 'eta': 28.7736, 'loss': 0.0003, 'lr': 0.0071, 'params': 379492, 'time_iter': 0.1073, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 145, 'eta': 28.6388, 'loss': 0.0003, 'lr': 0.0071, 'params': 379492, 'time_iter': 0.1002, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 146, 'eta': 28.5071, 'loss': 0.0003, 'lr': 0.0071, 'params': 379492, 'time_iter': 0.1018, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 147, 'eta': 28.3718, 'loss': 0.0003, 'lr': 0.007, 'params': 379492, 'time_iter': 0.0994, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 148, 'eta': 28.2317, 'loss': 0.0003, 'lr': 0.007, 'params': 379492, 'time_iter': 0.0962, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 149, 'eta': 28.1037, 'loss': 0.0003, 'lr': 0.0069, 'params': 379492, 'time_iter': 0.1032, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 150, 'eta': 27.9812, 'loss': 0.0003, 'lr': 0.0069, 'params': 379492, 'time_iter': 0.1063, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 151, 'eta': 27.841, 'loss': 0.0003, 'lr': 0.0069, 'params': 379492, 'time_iter': 0.0953, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 152, 'eta': 27.7204, 'loss': 0.0004, 'lr': 0.0068, 'params': 379492, 'time_iter': 0.1071, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 153, 'eta': 27.5959, 'loss': 0.0004, 'lr': 0.0068, 'params': 379492, 'time_iter': 0.1045, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 154, 'eta': 27.4823, 'loss': 0.0004, 'lr': 0.0068, 'params': 379492, 'time_iter': 0.1112, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 155, 'eta': 27.3459, 'loss': 0.0004, 'lr': 0.0067, 'params': 379492, 'time_iter': 0.0967, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 156, 'eta': 27.2159, 'loss': 0.0004, 'lr': 0.0067, 'params': 379492, 'time_iter': 0.1004, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 157, 'eta': 27.1191, 'loss': 0.0004, 'lr': 0.0067, 'params': 379492, 'time_iter': 0.1219, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 158, 'eta': 26.9866, 'loss': 0.0004, 'lr': 0.0066, 'params': 379492, 'time_iter': 0.0986, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 159, 'eta': 26.8562, 'loss': 0.0004, 'lr': 0.0066, 'params': 379492, 'time_iter': 0.0997, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 159, 'loss': 8.3178, 'lr': 0, 'params': 379492, 'time_iter': 0.0124, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 160, 'eta': 26.7305, 'loss': 0.0004, 'lr': 0.0065, 'params': 379492, 'time_iter': 0.1027, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 161, 'eta': 26.6042, 'loss': 0.0004, 'lr': 0.0065, 'params': 379492, 'time_iter': 0.102, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 162, 'eta': 26.4748, 'loss': 0.0004, 'lr': 0.0065, 'params': 379492, 'time_iter': 0.0997, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 163, 'eta': 26.3522, 'loss': 0.0004, 'lr': 0.0064, 'params': 379492, 'time_iter': 0.1042, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 164, 'eta': 26.2269, 'loss': 0.0004, 'lr': 0.0064, 'params': 379492, 'time_iter': 0.1021, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 165, 'eta': 26.097, 'loss': 0.0004, 'lr': 0.0064, 'params': 379492, 'time_iter': 0.0987, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 166, 'eta': 25.9827, 'loss': 0.0004, 'lr': 0.0063, 'params': 379492, 'time_iter': 0.1095, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 167, 'eta': 25.8603, 'loss': 0.0004, 'lr': 0.0063, 'params': 379492, 'time_iter': 0.1036, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 168, 'eta': 25.7422, 'loss': 0.0004, 'lr': 0.0062, 'params': 379492, 'time_iter': 0.1067, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 169, 'eta': 25.6253, 'loss': 0.0004, 'lr': 0.0062, 'params': 379492, 'time_iter': 0.1074, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 170, 'eta': 25.506, 'loss': 0.0004, 'lr': 0.0062, 'params': 379492, 'time_iter': 0.1055, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 171, 'eta': 25.3728, 'loss': 0.0004, 'lr': 0.0061, 'params': 379492, 'time_iter': 0.095, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 172, 'eta': 25.26, 'loss': 0.0004, 'lr': 0.0061, 'params': 379492, 'time_iter': 0.1101, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 173, 'eta': 25.1418, 'loss': 0.0004, 'lr': 0.0061, 'params': 379492, 'time_iter': 0.1059, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 174, 'eta': 25.0341, 'loss': 0.0004, 'lr': 0.006, 'params': 379492, 'time_iter': 0.1141, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 175, 'eta': 24.9063, 'loss': 0.0004, 'lr': 0.006, 'params': 379492, 'time_iter': 0.0982, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 176, 'eta': 24.7916, 'loss': 0.0004, 'lr': 0.0059, 'params': 379492, 'time_iter': 0.1084, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 177, 'eta': 24.66, 'loss': 0.0004, 'lr': 0.0059, 'params': 379492, 'time_iter': 0.0948, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 178, 'eta': 24.5389, 'loss': 0.0004, 'lr': 0.0059, 'params': 379492, 'time_iter': 0.103, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 179, 'eta': 24.4201, 'loss': 0.0004, 'lr': 0.0058, 'params': 379492, 'time_iter': 0.1046, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 179, 'loss': 8.1145, 'lr': 0, 'params': 379492, 'time_iter': 0.012, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 180, 'eta': 24.3419, 'loss': 0.0004, 'lr': 0.0058, 'params': 379492, 'time_iter': 0.1382, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 181, 'eta': 24.2164, 'loss': 0.0004, 'lr': 0.0057, 'params': 379492, 'time_iter': 0.0991, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 182, 'eta': 24.0971, 'loss': 0.0004, 'lr': 0.0057, 'params': 379492, 'time_iter': 0.1042, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 183, 'eta': 23.9716, 'loss': 0.0004, 'lr': 0.0057, 'params': 379492, 'time_iter': 0.0987, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 184, 'eta': 23.851, 'loss': 0.0004, 'lr': 0.0056, 'params': 379492, 'time_iter': 0.1027, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 185, 'eta': 23.7356, 'loss': 0.0004, 'lr': 0.0056, 'params': 379492, 'time_iter': 0.107, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 186, 'eta': 23.6174, 'loss': 0.0004, 'lr': 0.0055, 'params': 379492, 'time_iter': 0.1045, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 187, 'eta': 23.4812, 'loss': 0.0004, 'lr': 0.0055, 'params': 379492, 'time_iter': 0.0885, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 188, 'eta': 23.3591, 'loss': 0.0004, 'lr': 0.0055, 'params': 379492, 'time_iter': 0.1006, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 189, 'eta': 23.2362, 'loss': 0.0004, 'lr': 0.0054, 'params': 379492, 'time_iter': 0.0996, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 190, 'eta': 23.1059, 'loss': 0.0004, 'lr': 0.0054, 'params': 379492, 'time_iter': 0.0927, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 191, 'eta': 22.9873, 'loss': 0.0004, 'lr': 0.0054, 'params': 379492, 'time_iter': 0.1031, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 192, 'eta': 22.8774, 'loss': 0.0004, 'lr': 0.0053, 'params': 379492, 'time_iter': 0.1111, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 193, 'eta': 22.7603, 'loss': 0.0004, 'lr': 0.0053, 'params': 379492, 'time_iter': 0.1044, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 194, 'eta': 22.6452, 'loss': 0.0004, 'lr': 0.0052, 'params': 379492, 'time_iter': 0.1061, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 195, 'eta': 22.5333, 'loss': 0.0004, 'lr': 0.0052, 'params': 379492, 'time_iter': 0.109, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 196, 'eta': 22.4248, 'loss': 0.0004, 'lr': 0.0052, 'params': 379492, 'time_iter': 0.1124, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 197, 'eta': 22.3035, 'loss': 0.0004, 'lr': 0.0051, 'params': 379492, 'time_iter': 0.0998, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 198, 'eta': 22.1795, 'loss': 0.0004, 'lr': 0.0051, 'params': 379492, 'time_iter': 0.0969, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 199, 'eta': 22.0553, 'loss': 0.0004, 'lr': 0.005, 'params': 379492, 'time_iter': 0.0965, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 199, 'loss': 7.9604, 'lr': 0, 'params': 379492, 'time_iter': 0.0135, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 200, 'eta': 21.9312, 'loss': 0.0004, 'lr': 0.005, 'params': 379492, 'time_iter': 0.0963, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 201, 'eta': 21.8055, 'loss': 0.0004, 'lr': 0.005, 'params': 379492, 'time_iter': 0.0944, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 202, 'eta': 21.6766, 'loss': 0.0004, 'lr': 0.0049, 'params': 379492, 'time_iter': 0.0908, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 203, 'eta': 21.5516, 'loss': 0.0004, 'lr': 0.0049, 'params': 379492, 'time_iter': 0.0944, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# ...
# train: {'epoch': 329, 'eta': 7.6097, 'loss': 0.0005, 'lr': 0.0008, 'params': 379492, 'time_iter': 0.1012, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 330, 'eta': 7.521, 'loss': 0.0005, 'lr': 0.0007, 'params': 379492, 'time_iter': 0.2044, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 331, 'eta': 7.4083, 'loss': 0.0005, 'lr': 0.0007, 'params': 379492, 'time_iter': 0.0912, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 332, 'eta': 7.2951, 'loss': 0.0005, 'lr': 0.0007, 'params': 379492, 'time_iter': 0.0877, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 333, 'eta': 7.1833, 'loss': 0.0005, 'lr': 0.0007, 'params': 379492, 'time_iter': 0.0942, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 334, 'eta': 7.07, 'loss': 0.0005, 'lr': 0.0007, 'params': 379492, 'time_iter': 0.0856, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 335, 'eta': 6.9577, 'loss': 0.0005, 'lr': 0.0006, 'params': 379492, 'time_iter': 0.0903, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 336, 'eta': 6.8448, 'loss': 0.0005, 'lr': 0.0006, 'params': 379492, 'time_iter': 0.0867, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 337, 'eta': 6.7326, 'loss': 0.0005, 'lr': 0.0006, 'params': 379492, 'time_iter': 0.0889, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 338, 'eta': 6.6197, 'loss': 0.0005, 'lr': 0.0006, 'params': 379492, 'time_iter': 0.0848, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 339, 'eta': 6.5078, 'loss': 0.0005, 'lr': 0.0006, 'params': 379492, 'time_iter': 0.0892, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 339, 'loss': 7.3311, 'lr': 0, 'params': 379492, 'time_iter': 0.0296, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 340, 'eta': 6.3954, 'loss': 0.0005, 'lr': 0.0005, 'params': 379492, 'time_iter': 0.0857, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 341, 'eta': 6.2831, 'loss': 0.0005, 'lr': 0.0005, 'params': 379492, 'time_iter': 0.0854, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 342, 'eta': 6.171, 'loss': 0.0005, 'lr': 0.0005, 'params': 379492, 'time_iter': 0.0858, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 343, 'eta': 6.0595, 'loss': 0.0005, 'lr': 0.0005, 'params': 379492, 'time_iter': 0.0881, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 344, 'eta': 5.949, 'loss': 0.0005, 'lr': 0.0005, 'params': 379492, 'time_iter': 0.0937, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 345, 'eta': 5.8372, 'loss': 0.0005, 'lr': 0.0005, 'params': 379492, 'time_iter': 0.0855, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 346, 'eta': 5.7264, 'loss': 0.0005, 'lr': 0.0004, 'params': 379492, 'time_iter': 0.0904, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 347, 'eta': 5.6155, 'loss': 0.0005, 'lr': 0.0004, 'params': 379492, 'time_iter': 0.0886, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 348, 'eta': 5.5046, 'loss': 0.0005, 'lr': 0.0004, 'params': 379492, 'time_iter': 0.0879, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 349, 'eta': 5.3939, 'loss': 0.0005, 'lr': 0.0004, 'params': 379492, 'time_iter': 0.0887, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 350, 'eta': 5.2855, 'loss': 0.0005, 'lr': 0.0004, 'params': 379492, 'time_iter': 0.1044, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 351, 'eta': 5.1766, 'loss': 0.0005, 'lr': 0.0004, 'params': 379492, 'time_iter': 0.1006, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 352, 'eta': 5.0659, 'loss': 0.0005, 'lr': 0.0004, 'params': 379492, 'time_iter': 0.0863, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 353, 'eta': 4.9558, 'loss': 0.0005, 'lr': 0.0003, 'params': 379492, 'time_iter': 0.09, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 354, 'eta': 4.8453, 'loss': 0.0005, 'lr': 0.0003, 'params': 379492, 'time_iter': 0.0853, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 355, 'eta': 4.7356, 'loss': 0.0005, 'lr': 0.0003, 'params': 379492, 'time_iter': 0.0918, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 356, 'eta': 4.6256, 'loss': 0.0005, 'lr': 0.0003, 'params': 379492, 'time_iter': 0.0878, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 357, 'eta': 4.5164, 'loss': 0.0005, 'lr': 0.0003, 'params': 379492, 'time_iter': 0.0936, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 358, 'eta': 4.407, 'loss': 0.0005, 'lr': 0.0003, 'params': 379492, 'time_iter': 0.0908, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 359, 'eta': 4.2981, 'loss': 0.0005, 'lr': 0.0003, 'params': 379492, 'time_iter': 0.0951, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 359, 'loss': 7.296, 'lr': 0, 'params': 379492, 'time_iter': 0.0134, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 360, 'eta': 4.1889, 'loss': 0.0005, 'lr': 0.0002, 'params': 379492, 'time_iter': 0.0914, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 361, 'eta': 4.0796, 'loss': 0.0005, 'lr': 0.0002, 'params': 379492, 'time_iter': 0.0894, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 362, 'eta': 3.9703, 'loss': 0.0005, 'lr': 0.0002, 'params': 379492, 'time_iter': 0.0885, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 363, 'eta': 3.8608, 'loss': 0.0005, 'lr': 0.0002, 'params': 379492, 'time_iter': 0.0846, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 364, 'eta': 3.7519, 'loss': 0.0005, 'lr': 0.0002, 'params': 379492, 'time_iter': 0.0898, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 365, 'eta': 3.6428, 'loss': 0.0005, 'lr': 0.0002, 'params': 379492, 'time_iter': 0.0876, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 366, 'eta': 3.534, 'loss': 0.0005, 'lr': 0.0002, 'params': 379492, 'time_iter': 0.0878, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 367, 'eta': 3.4254, 'loss': 0.0005, 'lr': 0.0002, 'params': 379492, 'time_iter': 0.0898, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 368, 'eta': 3.3169, 'loss': 0.0005, 'lr': 0.0002, 'params': 379492, 'time_iter': 0.0901, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 369, 'eta': 3.2081, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0849, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 370, 'eta': 3.0997, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0885, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 371, 'eta': 2.9927, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.1046, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 372, 'eta': 2.885, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0962, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 373, 'eta': 2.7769, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0889, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 374, 'eta': 2.6693, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0943, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 375, 'eta': 2.5615, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0915, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 376, 'eta': 2.4537, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0881, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 377, 'eta': 2.3462, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0926, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 378, 'eta': 2.2385, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0877, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 379, 'eta': 2.1307, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0842, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 379, 'loss': 7.2734, 'lr': 0, 'params': 379492, 'time_iter': 0.0116, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 380, 'eta': 2.0234, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0915, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 381, 'eta': 1.9161, 'loss': 0.0005, 'lr': 0.0001, 'params': 379492, 'time_iter': 0.0885, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 382, 'eta': 1.8087, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.085, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 383, 'eta': 1.7014, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0858, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 384, 'eta': 1.5942, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0834, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 385, 'eta': 1.4871, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0844, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 386, 'eta': 1.3803, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0893, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 387, 'eta': 1.2734, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0811, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 388, 'eta': 1.1666, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0811, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 389, 'eta': 1.0599, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0841, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 390, 'eta': 0.9536, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0921, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 391, 'eta': 0.8473, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0885, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 392, 'eta': 0.7411, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.087, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 393, 'eta': 0.6349, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0878, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 394, 'eta': 0.5288, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.085, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 395, 'eta': 0.4229, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0908, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 396, 'eta': 0.3171, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0876, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 397, 'eta': 0.2113, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0876, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 398, 'eta': 0.1056, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0913, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 399, 'eta': 0.0, 'loss': 0.0005, 'lr': 0.0, 'params': 379492, 'time_iter': 0.0853, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 399, 'loss': 7.2627, 'lr': 0, 'params': 379492, 'time_iter': 0.0111, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# Task done, results saved in results/CCL3_GSE40240_eset
# 0
# {'epoch': 0, 'loss': 0.033, 'lr': 0, 'params': 379492, 'time_iter': 0.0183, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 0.0}
# {'epoch': 0, 'eta': 44.1146, 'loss': 0.8422, 'lr': 0.01, 'params': 379492, 'time_iter': 0.1106, 'accuracy': 0.5909, 'precision': 0.4545, 'recall': 0.625, 'f1': 0.5263, 'auc': 0.5893}
# End
# results/CCL3_GSE40240_eset/agg
# Results aggregated across runs saved in results/CCL3_GSE40240_eset/agg
# Visualization data stored at: Visuals/CCL3_GSE40240_eset_visuals.pt
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# 1
# True
# Model saved at models/CCL3_GSE40240_eset_1712361553.8439288_model.pt
# Traceback (most recent call last):
#   File "main.py", line 132, in <module>
#     Print("Experiment name: " + name)
# NameError: name 'Print' is not defined
# Start Time is: 2024-04-05 16:58:05
# End Time is: 2024-04-05 16:59:14

# %% [markdown]
# # Retreive latent data for visualizations
#
# Look near the end for location of the visuals (Line like "Visualization data stored at: ")

# %%
import torch

visual_data = torch.load("Visuals/CCL3_GSE40240_eset_visuals.pt")

latent_data = visual_data['latent']
label_data = visual_data['truth']

# %%
from Visualization import Visualize

Visualize.visualize_PCA(latent_data, label_data)
Visualize.visualize_TSNE(latent_data, label_data)
# Out:
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
# visualize graph data
graph_visual_data = visual_data['graph_data']
Visualize.visualize_graph(graph_visual_data['colours'], graph_visual_data['graph'],graph_visual_data['name'], graph_visual_data['edge_weights'])
