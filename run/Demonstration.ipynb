# %%
# !python -V
# Out:
# Python 3.7.16

# %% [markdown]
# #Train Model

# %%
# %cd ../
# !pip install -e .
# %cd run
# Out:
# /home/royhe62/Documents/Dockers/cypress/iCypressParallel
# Obtaining file:///home/royhe62/Documents/Dockers/cypress/iCypressParallel
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: yacs in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (0.1.8)
# Requirement already satisfied: tensorboardx in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (2.6.2.2)
# Requirement already satisfied: torch in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (1.8.0+cu101)
# Requirement already satisfied: torch-geometric in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (2.2.0)
# Requirement already satisfied: networkx in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (2.6.3)
# Requirement already satisfied: numpy in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (1.21.6)
# Requirement already satisfied: deepsnap in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (0.2.1)
# Requirement already satisfied: ogb in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from graphgym==0.4.0) (1.3.6)
# Requirement already satisfied: tqdm>=4.29.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (4.66.1)
# Requirement already satisfied: outdated>=0.2.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (2.0.7)
# Requirement already satisfied: pandas>=0.24.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from ogb->graphgym==0.4.0) (1.0.2)
# Requirement already satisfied: typing-extensions in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch->graphgym==0.4.0) (4.7.1)
# Requirement already satisfied: protobuf>=3.20 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from tensorboardx->graphgym==0.4.0) (4.24.4)
# Requirement already satisfied: packaging in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from tensorboardx->graphgym==0.4.0) (23.2)
# Requirement already satisfied: jinja2 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch-geometric->graphgym==0.4.0) (3.1.3)
# Requirement already satisfied: psutil>=5.8.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch-geometric->graphgym==0.4.0) (5.9.7)
# Requirement already satisfied: pyparsing in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch-geometric->graphgym==0.4.0) (3.1.1)
# Requirement already satisfied: scipy in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch-geometric->graphgym==0.4.0) (1.7.3)
# Requirement already satisfied: requests in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from torch-geometric->graphgym==0.4.0) (2.31.0)
# Requirement already satisfied: PyYAML in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from yacs->graphgym==0.4.0) (6.0.1)
# Requirement already satisfied: littleutils in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from outdated>=0.2.0->ogb->graphgym==0.4.0) (0.2.2)
# Requirement already satisfied: setuptools>=44 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from outdated>=0.2.0->ogb->graphgym==0.4.0) (65.6.3)
# Requirement already satisfied: pytz>=2017.3 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from pandas>=0.24.0->ogb->graphgym==0.4.0) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from pandas>=0.24.0->ogb->graphgym==0.4.0) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from scikit-learn>=0.20.0->ogb->graphgym==0.4.0) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from scikit-learn>=0.20.0->ogb->graphgym==0.4.0) (1.3.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from jinja2->torch-geometric->graphgym==0.4.0) (2.1.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from requests->torch-geometric->graphgym==0.4.0) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from requests->torch-geometric->graphgym==0.4.0) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages (from requests->torch-geometric->graphgym==0.4.0) (2022.12.7)
# Installing collected packages: graphgym
#   Attempting uninstall: graphgym
#     Found existing installation: graphgym 0.4.0
#     Uninstalling graphgym-0.4.0:
#       Successfully uninstalled graphgym-0.4.0
#   Running setup.py develop for graphgym
# Successfully installed graphgym-0.4.0
# /home/royhe62/Documents/Dockers/cypress/iCypressParallel/run

# %%
# !bash custom.sh GSE40240_eset GSE40240_patients CCL1 False NULL NULL True
# Out:
# CCL1_GSE40240_eset
# Processing...
# CCL1_GSE40240_eset
# Done!
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/torch_geometric/graphgym/imports.py:14: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/torch_geometric/graphgym/logger.py:23: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "
# WARNING:root:dataset.transductive changed to False for graph task.
# Load: 0.02954s, Before split: 0.0002501s, Split: 7.772e-05s, After split: 0.0004802s
# GNN(
#   (preprocess): Preprocess(
#     node_feature: dim_out=119
#     Total: dim_out=119
#   )
#   (pre_mp): GeneralMultiLayer(
#     (Layer_0): GeneralLayer(
#       (layer): Linear(
#         (model): Linear(in_features=119, out_features=137, bias=False)
#       )
#       (post_layer): Sequential(
#         (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): PReLU(num_parameters=1)
#       )
#     )
#     (Layer_1): GeneralLayer(
#       (layer): Linear(
#         (model): Linear(in_features=137, out_features=137, bias=False)
#       )
#       (post_layer): Sequential(
#         (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): PReLU(num_parameters=1)
#       )
#     )
#   )
#   (mp): GNNSkipStage(
#     (block0): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block1): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block2): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block3): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block4): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block5): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#   )
#   (post_mp): GNNGraphHead(
#     (layer_post_mp): MLP(
#       (model): Sequential(
#         (0): GeneralMultiLayer(
#           (Layer_0): GeneralLayer(
#             (layer): Linear(
#               (model): Linear(in_features=137, out_features=137, bias=False)
#             )
#             (post_layer): Sequential(
#               (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): PReLU(num_parameters=1)
#             )
#           )
#         )
#         (1): Linear(
#           (model): Linear(in_features=137, out_features=1, bias=True)
#         )
#       )
#     )
#   )
# )
# bn:
#   eps: 1e-05
#   mom: 0.1
# cfg_dest: config.yaml
# custom_metrics: []
# dataset:
#   augment_feature: []
#   augment_feature_dims: []
#   augment_feature_repr: position
#   augment_label:
#   augment_label_dims: 0
#   cache_load: False
#   cache_save: False
#   dir: ./datasets
#   edge_dim: 128
#   edge_encoder: False
#   edge_encoder_bn: True
#   edge_encoder_name: Bond
#   edge_message_ratio: 0.8
#   edge_negative_sampling_ratio: 1.0
#   edge_train_mode: all
#   encoder: True
#   encoder_bn: True
#   encoder_dim: 128
#   encoder_name: db
#   format: PyG
#   label_column: none
#   label_table: none
#   location: local
#   name: Custom,CCL1_GSE40240_eset,,
#   node_encoder: False
#   node_encoder_bn: True
#   node_encoder_name: Atom
#   remove_feature: False
#   resample_disjoint: False
#   resample_negative: False
#   shuffle_split: True
#   split: [0.8, 0.2]
#   split_mode: random
#   task: graph
#   task_type: classification
#   to_undirected: False
#   transductive: False
#   transform: none
#   tu_simple: True
# device: cpu
# example_arg: example
# example_group:
#   example_arg: example
# gnn:
#   act: prelu
#   agg: add
#   att_final_linear: False
#   att_final_linear_bn: False
#   att_heads: 1
#   batchnorm: True
#   clear_feature: True
#   dim_inner: 137
#   dropout: 0.0
#   flow: source_to_target
#   head: graph
#   keep_edge: 0.5
#   l2norm: True
#   layer_type: generalconv
#   layers_mp: 6
#   layers_post_mp: 2
#   layers_pre_mp: 2
#   msg_direction: single
#   normalize_adj: False
#   self_msg: concat
#   skip_every: 1
#   stage_type: skipsum
# gpu_mem: False
# mem:
#   inplace: False
# metric_agg: argmax
# metric_best: auto
# model:
#   edge_decoding: dot
#   graph_pooling: add
#   loss_fun: cross_entropy
#   match_upper: True
#   size_average: mean
#   thresh: 0.5
#   type: gnn
# num_threads: 6
# num_workers: 0
# optim:
#   base_lr: 0.01
#   lr_decay: 0.1
#   max_epoch: 400
#   momentum: 0.9
#   optimizer: adam
#   scheduler: cos
#   steps: [30, 60, 90]
#   weight_decay: 0.0005
# out_dir: results/CCL1_GSE40240_eset
# print: both
# round: 4
# run_dir: results/CCL1_GSE40240_eset/0
# seed: 1
# share:
#   dim_in: 119
#   dim_out: 1
#   num_splits: 2
# tensorboard_agg: True
# tensorboard_each_run: False
# train:
#   auto_resume: False
#   batch_size: 80
#   ckpt_clean: True
#   ckpt_period: 100
#   enable_ckpt: True
#   epoch_resume: -1
#   eval_period: 20
#   iter_per_epoch: 32
#   mode: standard
#   neighbor_sizes: [20, 15, 10, 5]
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
#   skip_train_eval: False
#   walk_length: 4
# val:
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
# view_emb: False
# Num parameters: 281674
# Start from epoch 0
# train: {'epoch': 0, 'eta': 18.5063, 'loss': 1.1845, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0464, 'accuracy': 0.3636, 'precision': 0.2, 'recall': 0.25, 'f1': 0.2222, 'auc': 0.3036}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 0, 'loss': 1.769, 'lr': 0, 'params': 281674, 'time_iter': 0.0069, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 1, 'eta': 17.7625, 'loss': 0.9891, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0429, 'accuracy': 0.7273, 'precision': 0.5833, 'recall': 0.875, 'f1': 0.7, 'auc': 0.8125}
# train: {'epoch': 2, 'eta': 17.6989, 'loss': 1.0769, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0445, 'accuracy': 0.7727, 'precision': 0.6667, 'recall': 0.75, 'f1': 0.7059, 'auc': 0.7411}
# train: {'epoch': 3, 'eta': 17.5365, 'loss': 0.1538, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0434, 'accuracy': 0.9091, 'precision': 0.875, 'recall': 0.875, 'f1': 0.875, 'auc': 0.9911}
# train: {'epoch': 4, 'eta': 17.3428, 'loss': 0.0818, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0424, 'accuracy': 0.9545, 'precision': 0.8889, 'recall': 1.0, 'f1': 0.9412, 'auc': 1.0}
# train: {'epoch': 5, 'eta': 17.1976, 'loss': 0.0326, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0424, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 6, 'eta': 16.9794, 'loss': 0.0213, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0405, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 7, 'eta': 16.4177, 'loss': 0.0185, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0326, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 8, 'eta': 16.2328, 'loss': 0.0097, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0386, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 9, 'eta': 16.3045, 'loss': 0.0054, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0444, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 10, 'eta': 16.2248, 'loss': 0.0037, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0407, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 11, 'eta': 16.1839, 'loss': 0.0029, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0417, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 12, 'eta': 16.1027, 'loss': 0.0024, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0404, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 13, 'eta': 16.0624, 'loss': 0.0021, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0417, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 14, 'eta': 15.9613, 'loss': 0.0018, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0393, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 15, 'eta': 15.69, 'loss': 0.0015, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0319, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 16, 'eta': 15.5739, 'loss': 0.0014, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0375, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 17, 'eta': 15.4933, 'loss': 0.0012, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0388, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 18, 'eta': 15.4598, 'loss': 0.0011, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0409, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 19, 'eta': 15.4837, 'loss': 0.001, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.044, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 19, 'loss': 3.5808, 'lr': 0, 'params': 281674, 'time_iter': 0.0053, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 20, 'eta': 15.4783, 'loss': 0.0009, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0427, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 21, 'eta': 15.5005, 'loss': 0.0008, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0445, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 22, 'eta': 15.5119, 'loss': 0.0008, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0442, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 23, 'eta': 15.4915, 'loss': 0.0007, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0425, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 24, 'eta': 15.4689, 'loss': 0.0007, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0424, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 25, 'eta': 15.4525, 'loss': 0.0007, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.043, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 26, 'eta': 15.4121, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0414, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 27, 'eta': 15.3649, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0409, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 28, 'eta': 15.324, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0413, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 29, 'eta': 15.2094, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0354, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 30, 'eta': 15.2174, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0452, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 31, 'eta': 15.2244, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0454, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 32, 'eta': 15.192, 'loss': 0.0006, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0422, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 33, 'eta': 15.1653, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0428, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 34, 'eta': 15.149, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0438, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 35, 'eta': 15.1258, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0433, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 36, 'eta': 15.0847, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0416, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 37, 'eta': 15.0567, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.043, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 38, 'eta': 14.9932, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0392, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 39, 'eta': 14.9369, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0399, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 39, 'loss': 6.7528, 'lr': 0, 'params': 281674, 'time_iter': 0.0055, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 40, 'eta': 14.9076, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0429, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 41, 'eta': 14.869, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0419, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 42, 'eta': 14.7483, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.032, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 43, 'eta': 14.6553, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0349, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 44, 'eta': 14.6597, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0469, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 45, 'eta': 14.6347, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0434, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 46, 'eta': 14.6144, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0441, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 47, 'eta': 14.5767, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0419, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 48, 'eta': 14.536, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0415, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 49, 'eta': 14.5412, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0481, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 50, 'eta': 14.5291, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0459, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 51, 'eta': 14.5981, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0582, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 52, 'eta': 14.6406, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0548, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 53, 'eta': 14.6556, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0511, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 54, 'eta': 14.6437, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0472, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 55, 'eta': 14.6094, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0438, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 56, 'eta': 14.527, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0358, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 57, 'eta': 14.4539, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0371, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 58, 'eta': 14.404, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0409, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 59, 'eta': 14.3688, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0435, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 59, 'loss': 7.7289, 'lr': 0, 'params': 281674, 'time_iter': 0.0068, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 60, 'eta': 14.3442, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0454, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 61, 'eta': 14.3103, 'loss': 0.0004, 'lr': 0.0094, 'params': 281674, 'time_iter': 0.0439, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 62, 'eta': 14.2927, 'loss': 0.0004, 'lr': 0.0094, 'params': 281674, 'time_iter': 0.047, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 63, 'eta': 14.2736, 'loss': 0.0004, 'lr': 0.0094, 'params': 281674, 'time_iter': 0.0469, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 64, 'eta': 14.2507, 'loss': 0.0004, 'lr': 0.0094, 'params': 281674, 'time_iter': 0.0463, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 65, 'eta': 14.2267, 'loss': 0.0004, 'lr': 0.0094, 'params': 281674, 'time_iter': 0.0462, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 66, 'eta': 14.1907, 'loss': 0.0004, 'lr': 0.0093, 'params': 281674, 'time_iter': 0.0439, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 67, 'eta': 14.1501, 'loss': 0.0004, 'lr': 0.0093, 'params': 281674, 'time_iter': 0.043, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 68, 'eta': 14.1094, 'loss': 0.0004, 'lr': 0.0093, 'params': 281674, 'time_iter': 0.043, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 69, 'eta': 14.0729, 'loss': 0.0004, 'lr': 0.0093, 'params': 281674, 'time_iter': 0.0439, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 70, 'eta': 14.0741, 'loss': 0.0004, 'lr': 0.0093, 'params': 281674, 'time_iter': 0.0521, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 71, 'eta': 14.0662, 'loss': 0.0004, 'lr': 0.0092, 'params': 281674, 'time_iter': 0.0504, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 72, 'eta': 14.049, 'loss': 0.0004, 'lr': 0.0092, 'params': 281674, 'time_iter': 0.0486, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 73, 'eta': 14.028, 'loss': 0.0004, 'lr': 0.0092, 'params': 281674, 'time_iter': 0.0479, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 74, 'eta': 13.9951, 'loss': 0.0004, 'lr': 0.0092, 'params': 281674, 'time_iter': 0.0454, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 75, 'eta': 13.9541, 'loss': 0.0004, 'lr': 0.0092, 'params': 281674, 'time_iter': 0.0436, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 76, 'eta': 13.9107, 'loss': 0.0004, 'lr': 0.0091, 'params': 281674, 'time_iter': 0.043, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 77, 'eta': 13.8818, 'loss': 0.0004, 'lr': 0.0091, 'params': 281674, 'time_iter': 0.0465, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 78, 'eta': 13.8364, 'loss': 0.0004, 'lr': 0.0091, 'params': 281674, 'time_iter': 0.0425, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 79, 'eta': 13.8125, 'loss': 0.0004, 'lr': 0.0091, 'params': 281674, 'time_iter': 0.0479, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 79, 'loss': 7.6715, 'lr': 0, 'params': 281674, 'time_iter': 0.0089, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 80, 'eta': 13.7709, 'loss': 0.0004, 'lr': 0.009, 'params': 281674, 'time_iter': 0.0436, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 81, 'eta': 13.7281, 'loss': 0.0004, 'lr': 0.009, 'params': 281674, 'time_iter': 0.0433, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 82, 'eta': 13.7041, 'loss': 0.0004, 'lr': 0.009, 'params': 281674, 'time_iter': 0.0482, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 83, 'eta': 13.6817, 'loss': 0.0004, 'lr': 0.009, 'params': 281674, 'time_iter': 0.0487, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 84, 'eta': 13.6612, 'loss': 0.0004, 'lr': 0.009, 'params': 281674, 'time_iter': 0.0495, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 85, 'eta': 13.6538, 'loss': 0.0004, 'lr': 0.0089, 'params': 281674, 'time_iter': 0.0532, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 86, 'eta': 13.6454, 'loss': 0.0004, 'lr': 0.0089, 'params': 281674, 'time_iter': 0.0532, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 87, 'eta': 13.6095, 'loss': 0.0004, 'lr': 0.0089, 'params': 281674, 'time_iter': 0.0458, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 88, 'eta': 13.5791, 'loss': 0.0004, 'lr': 0.0089, 'params': 281674, 'time_iter': 0.0474, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 89, 'eta': 13.5538, 'loss': 0.0004, 'lr': 0.0088, 'params': 281674, 'time_iter': 0.049, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 90, 'eta': 13.5085, 'loss': 0.0004, 'lr': 0.0088, 'params': 281674, 'time_iter': 0.0433, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 91, 'eta': 13.4659, 'loss': 0.0004, 'lr': 0.0088, 'params': 281674, 'time_iter': 0.0441, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 92, 'eta': 13.4233, 'loss': 0.0004, 'lr': 0.0088, 'params': 281674, 'time_iter': 0.044, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 93, 'eta': 13.3803, 'loss': 0.0004, 'lr': 0.0087, 'params': 281674, 'time_iter': 0.044, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 94, 'eta': 13.3351, 'loss': 0.0004, 'lr': 0.0087, 'params': 281674, 'time_iter': 0.0433, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 95, 'eta': 13.3125, 'loss': 0.0004, 'lr': 0.0087, 'params': 281674, 'time_iter': 0.0504, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 96, 'eta': 13.2922, 'loss': 0.0004, 'lr': 0.0086, 'params': 281674, 'time_iter': 0.0513, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 97, 'eta': 13.2549, 'loss': 0.0004, 'lr': 0.0086, 'params': 281674, 'time_iter': 0.046, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 98, 'eta': 13.2243, 'loss': 0.0004, 'lr': 0.0086, 'params': 281674, 'time_iter': 0.0483, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 99, 'eta': 13.1866, 'loss': 0.0004, 'lr': 0.0086, 'params': 281674, 'time_iter': 0.046, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 99, 'loss': 7.403, 'lr': 0, 'params': 281674, 'time_iter': 0.0071, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 100, 'eta': 13.1512, 'loss': 0.0004, 'lr': 0.0085, 'params': 281674, 'time_iter': 0.0468, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 101, 'eta': 13.1101, 'loss': 0.0004, 'lr': 0.0085, 'params': 281674, 'time_iter': 0.045, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 102, 'eta': 13.0773, 'loss': 0.0004, 'lr': 0.0085, 'params': 281674, 'time_iter': 0.0479, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 103, 'eta': 13.0407, 'loss': 0.0004, 'lr': 0.0085, 'params': 281674, 'time_iter': 0.0467, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 104, 'eta': 12.9979, 'loss': 0.0004, 'lr': 0.0084, 'params': 281674, 'time_iter': 0.0445, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 105, 'eta': 12.9661, 'loss': 0.0004, 'lr': 0.0084, 'params': 281674, 'time_iter': 0.0485, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 106, 'eta': 12.9139, 'loss': 0.0004, 'lr': 0.0084, 'params': 281674, 'time_iter': 0.0412, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 107, 'eta': 12.8679, 'loss': 0.0004, 'lr': 0.0083, 'params': 281674, 'time_iter': 0.0434, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 108, 'eta': 12.8246, 'loss': 0.0004, 'lr': 0.0083, 'params': 281674, 'time_iter': 0.0444, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 109, 'eta': 12.7802, 'loss': 0.0004, 'lr': 0.0083, 'params': 281674, 'time_iter': 0.044, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 110, 'eta': 12.7402, 'loss': 0.0004, 'lr': 0.0082, 'params': 281674, 'time_iter': 0.0457, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 111, 'eta': 12.6955, 'loss': 0.0004, 'lr': 0.0082, 'params': 281674, 'time_iter': 0.0438, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 112, 'eta': 12.6627, 'loss': 0.0004, 'lr': 0.0082, 'params': 281674, 'time_iter': 0.0485, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 113, 'eta': 12.6404, 'loss': 0.0004, 'lr': 0.0082, 'params': 281674, 'time_iter': 0.0528, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 114, 'eta': 12.6084, 'loss': 0.0004, 'lr': 0.0081, 'params': 281674, 'time_iter': 0.0491, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 115, 'eta': 12.564, 'loss': 0.0004, 'lr': 0.0081, 'params': 281674, 'time_iter': 0.0442, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 116, 'eta': 12.568, 'loss': 0.0004, 'lr': 0.0081, 'params': 281674, 'time_iter': 0.0642, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 117, 'eta': 12.5092, 'loss': 0.0004, 'lr': 0.008, 'params': 281674, 'time_iter': 0.0384, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 118, 'eta': 12.4719, 'loss': 0.0004, 'lr': 0.008, 'params': 281674, 'time_iter': 0.0474, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 119, 'eta': 12.4325, 'loss': 0.0004, 'lr': 0.008, 'params': 281674, 'time_iter': 0.0465, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 119, 'loss': 7.2298, 'lr': 0, 'params': 281674, 'time_iter': 0.0058, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 120, 'eta': 12.4195, 'loss': 0.0004, 'lr': 0.0079, 'params': 281674, 'time_iter': 0.058, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 121, 'eta': 12.3859, 'loss': 0.0004, 'lr': 0.0079, 'params': 281674, 'time_iter': 0.0493, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 122, 'eta': 12.3363, 'loss': 0.0004, 'lr': 0.0079, 'params': 281674, 'time_iter': 0.0423, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 123, 'eta': 12.2719, 'loss': 0.0004, 'lr': 0.0078, 'params': 281674, 'time_iter': 0.0356, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 124, 'eta': 12.2339, 'loss': 0.0004, 'lr': 0.0078, 'params': 281674, 'time_iter': 0.0474, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 125, 'eta': 12.1804, 'loss': 0.0004, 'lr': 0.0078, 'params': 281674, 'time_iter': 0.0404, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 126, 'eta': 12.1651, 'loss': 0.0004, 'lr': 0.0077, 'params': 281674, 'time_iter': 0.058, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 127, 'eta': 12.1251, 'loss': 0.0004, 'lr': 0.0077, 'params': 281674, 'time_iter': 0.0467, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 128, 'eta': 12.0849, 'loss': 0.0004, 'lr': 0.0077, 'params': 281674, 'time_iter': 0.0467, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 129, 'eta': 12.042, 'loss': 0.0004, 'lr': 0.0076, 'params': 281674, 'time_iter': 0.0454, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 130, 'eta': 11.9921, 'loss': 0.0004, 'lr': 0.0076, 'params': 281674, 'time_iter': 0.042, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 131, 'eta': 11.9286, 'loss': 0.0004, 'lr': 0.0076, 'params': 281674, 'time_iter': 0.0353, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 132, 'eta': 11.8829, 'loss': 0.0004, 'lr': 0.0075, 'params': 281674, 'time_iter': 0.0439, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 133, 'eta': 11.8438, 'loss': 0.0004, 'lr': 0.0075, 'params': 281674, 'time_iter': 0.0472, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 134, 'eta': 11.8099, 'loss': 0.0004, 'lr': 0.0075, 'params': 281674, 'time_iter': 0.0499, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 135, 'eta': 11.7578, 'loss': 0.0004, 'lr': 0.0074, 'params': 281674, 'time_iter': 0.0407, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 136, 'eta': 11.7189, 'loss': 0.0004, 'lr': 0.0074, 'params': 281674, 'time_iter': 0.0475, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 137, 'eta': 11.6686, 'loss': 0.0004, 'lr': 0.0074, 'params': 281674, 'time_iter': 0.0416, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 138, 'eta': 11.6269, 'loss': 0.0004, 'lr': 0.0073, 'params': 281674, 'time_iter': 0.046, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 139, 'eta': 11.5868, 'loss': 0.0004, 'lr': 0.0073, 'params': 281674, 'time_iter': 0.0469, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 139, 'loss': 7.108, 'lr': 0, 'params': 281674, 'time_iter': 0.0056, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 140, 'eta': 11.5642, 'loss': 0.0004, 'lr': 0.0073, 'params': 281674, 'time_iter': 0.0565, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 141, 'eta': 11.5318, 'loss': 0.0004, 'lr': 0.0072, 'params': 281674, 'time_iter': 0.0514, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 142, 'eta': 11.5056, 'loss': 0.0004, 'lr': 0.0072, 'params': 281674, 'time_iter': 0.055, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 143, 'eta': 11.4779, 'loss': 0.0004, 'lr': 0.0072, 'params': 281674, 'time_iter': 0.0544, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 144, 'eta': 11.4364, 'loss': 0.0004, 'lr': 0.0071, 'params': 281674, 'time_iter': 0.0467, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 145, 'eta': 11.3892, 'loss': 0.0004, 'lr': 0.0071, 'params': 281674, 'time_iter': 0.0435, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 146, 'eta': 11.3411, 'loss': 0.0004, 'lr': 0.0071, 'params': 281674, 'time_iter': 0.043, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 147, 'eta': 11.2892, 'loss': 0.0004, 'lr': 0.007, 'params': 281674, 'time_iter': 0.0407, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 148, 'eta': 11.2495, 'loss': 0.0004, 'lr': 0.007, 'params': 281674, 'time_iter': 0.0478, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 149, 'eta': 11.2214, 'loss': 0.0005, 'lr': 0.0069, 'params': 281674, 'time_iter': 0.0549, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 150, 'eta': 11.1818, 'loss': 0.0005, 'lr': 0.0069, 'params': 281674, 'time_iter': 0.0481, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 151, 'eta': 11.134, 'loss': 0.0005, 'lr': 0.0069, 'params': 281674, 'time_iter': 0.0431, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 152, 'eta': 11.0977, 'loss': 0.0005, 'lr': 0.0068, 'params': 281674, 'time_iter': 0.0502, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 153, 'eta': 11.0489, 'loss': 0.0005, 'lr': 0.0068, 'params': 281674, 'time_iter': 0.0425, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 154, 'eta': 11.0035, 'loss': 0.0005, 'lr': 0.0068, 'params': 281674, 'time_iter': 0.0446, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 155, 'eta': 10.9517, 'loss': 0.0005, 'lr': 0.0067, 'params': 281674, 'time_iter': 0.0405, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 156, 'eta': 10.8889, 'loss': 0.0005, 'lr': 0.0067, 'params': 281674, 'time_iter': 0.0333, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 157, 'eta': 10.8498, 'loss': 0.0005, 'lr': 0.0067, 'params': 281674, 'time_iter': 0.0486, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 158, 'eta': 10.8039, 'loss': 0.0005, 'lr': 0.0066, 'params': 281674, 'time_iter': 0.0441, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 159, 'eta': 10.7651, 'loss': 0.0005, 'lr': 0.0066, 'params': 281674, 'time_iter': 0.0489, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 159, 'loss': 7.0053, 'lr': 0, 'params': 281674, 'time_iter': 0.0063, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 160, 'eta': 10.7368, 'loss': 0.0005, 'lr': 0.0065, 'params': 281674, 'time_iter': 0.056, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 161, 'eta': 10.7058, 'loss': 0.0005, 'lr': 0.0065, 'params': 281674, 'time_iter': 0.0544, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 162, 'eta': 10.6601, 'loss': 0.0005, 'lr': 0.0065, 'params': 281674, 'time_iter': 0.0445, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 163, 'eta': 10.6127, 'loss': 0.0005, 'lr': 0.0064, 'params': 281674, 'time_iter': 0.0433, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 164, 'eta': 10.5612, 'loss': 0.0005, 'lr': 0.0064, 'params': 281674, 'time_iter': 0.0404, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 165, 'eta': 10.513, 'loss': 0.0005, 'lr': 0.0064, 'params': 281674, 'time_iter': 0.0427, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 166, 'eta': 10.4696, 'loss': 0.0005, 'lr': 0.0063, 'params': 281674, 'time_iter': 0.046, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 167, 'eta': 10.4235, 'loss': 0.0005, 'lr': 0.0063, 'params': 281674, 'time_iter': 0.0441, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 168, 'eta': 10.3764, 'loss': 0.0005, 'lr': 0.0062, 'params': 281674, 'time_iter': 0.0433, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 169, 'eta': 10.3277, 'loss': 0.0005, 'lr': 0.0062, 'params': 281674, 'time_iter': 0.0421, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 170, 'eta': 10.2775, 'loss': 0.0005, 'lr': 0.0062, 'params': 281674, 'time_iter': 0.0409, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 171, 'eta': 10.2286, 'loss': 0.0005, 'lr': 0.0061, 'params': 281674, 'time_iter': 0.0418, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 172, 'eta': 10.1811, 'loss': 0.0005, 'lr': 0.0061, 'params': 281674, 'time_iter': 0.0429, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 173, 'eta': 10.1362, 'loss': 0.0005, 'lr': 0.0061, 'params': 281674, 'time_iter': 0.0448, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 174, 'eta': 10.1, 'loss': 0.0005, 'lr': 0.006, 'params': 281674, 'time_iter': 0.0516, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 175, 'eta': 10.0602, 'loss': 0.0005, 'lr': 0.006, 'params': 281674, 'time_iter': 0.0489, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 176, 'eta': 10.0189, 'loss': 0.0005, 'lr': 0.0059, 'params': 281674, 'time_iter': 0.0478, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 177, 'eta': 9.9744, 'loss': 0.0005, 'lr': 0.0059, 'params': 281674, 'time_iter': 0.0453, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 178, 'eta': 9.9268, 'loss': 0.0005, 'lr': 0.0059, 'params': 281674, 'time_iter': 0.0428, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 179, 'eta': 9.8776, 'loss': 0.0005, 'lr': 0.0058, 'params': 281674, 'time_iter': 0.0414, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 179, 'loss': 6.9166, 'lr': 0, 'params': 281674, 'time_iter': 0.006, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 180, 'eta': 9.837, 'loss': 0.0005, 'lr': 0.0058, 'params': 281674, 'time_iter': 0.0485, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 181, 'eta': 9.7979, 'loss': 0.0005, 'lr': 0.0057, 'params': 281674, 'time_iter': 0.0498, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 182, 'eta': 9.757, 'loss': 0.0005, 'lr': 0.0057, 'params': 281674, 'time_iter': 0.0484, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 183, 'eta': 9.7156, 'loss': 0.0005, 'lr': 0.0057, 'params': 281674, 'time_iter': 0.0479, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 184, 'eta': 9.6723, 'loss': 0.0005, 'lr': 0.0056, 'params': 281674, 'time_iter': 0.0465, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 185, 'eta': 9.6265, 'loss': 0.0005, 'lr': 0.0056, 'params': 281674, 'time_iter': 0.0442, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 186, 'eta': 9.5831, 'loss': 0.0005, 'lr': 0.0055, 'params': 281674, 'time_iter': 0.0464, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 187, 'eta': 9.55, 'loss': 0.0005, 'lr': 0.0055, 'params': 281674, 'time_iter': 0.0555, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 188, 'eta': 9.5214, 'loss': 0.0005, 'lr': 0.0055, 'params': 281674, 'time_iter': 0.0598, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 189, 'eta': 9.4868, 'loss': 0.0005, 'lr': 0.0054, 'params': 281674, 'time_iter': 0.0547, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 190, 'eta': 9.4481, 'loss': 0.0005, 'lr': 0.0054, 'params': 281674, 'time_iter': 0.051, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 191, 'eta': 9.4094, 'loss': 0.0005, 'lr': 0.0054, 'params': 281674, 'time_iter': 0.0512, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 192, 'eta': 9.3721, 'loss': 0.0005, 'lr': 0.0053, 'params': 281674, 'time_iter': 0.0526, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 193, 'eta': 9.32, 'loss': 0.0005, 'lr': 0.0053, 'params': 281674, 'time_iter': 0.0389, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 194, 'eta': 9.2803, 'loss': 0.0005, 'lr': 0.0052, 'params': 281674, 'time_iter': 0.0505, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 195, 'eta': 9.2331, 'loss': 0.0005, 'lr': 0.0052, 'params': 281674, 'time_iter': 0.0434, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 196, 'eta': 9.1899, 'loss': 0.0005, 'lr': 0.0052, 'params': 281674, 'time_iter': 0.0473, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 197, 'eta': 9.1434, 'loss': 0.0005, 'lr': 0.0051, 'params': 281674, 'time_iter': 0.0441, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 198, 'eta': 9.102, 'loss': 0.0005, 'lr': 0.0051, 'params': 281674, 'time_iter': 0.0491, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 199, 'eta': 9.0591, 'loss': 0.0005, 'lr': 0.005, 'params': 281674, 'time_iter': 0.0476, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# train: {'epoch': 327, 'eta': 3.229, 'loss': 0.0005, 'lr': 0.0008, 'params': 281674, 'time_iter': 0.0446, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 328, 'eta': 3.1842, 'loss': 0.0005, 'lr': 0.0008, 'params': 281674, 'time_iter': 0.045, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 329, 'eta': 3.1392, 'loss': 0.0005, 'lr': 0.0008, 'params': 281674, 'time_iter': 0.0443, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 330, 'eta': 3.0941, 'loss': 0.0005, 'lr': 0.0007, 'params': 281674, 'time_iter': 0.0437, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 331, 'eta': 3.0498, 'loss': 0.0005, 'lr': 0.0007, 'params': 281674, 'time_iter': 0.0471, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 332, 'eta': 3.0051, 'loss': 0.0005, 'lr': 0.0007, 'params': 281674, 'time_iter': 0.0457, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 333, 'eta': 2.9602, 'loss': 0.0005, 'lr': 0.0007, 'params': 281674, 'time_iter': 0.0445, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 334, 'eta': 2.915, 'loss': 0.0005, 'lr': 0.0007, 'params': 281674, 'time_iter': 0.0431, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 335, 'eta': 2.8698, 'loss': 0.0005, 'lr': 0.0006, 'params': 281674, 'time_iter': 0.0431, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 336, 'eta': 2.8246, 'loss': 0.0005, 'lr': 0.0006, 'params': 281674, 'time_iter': 0.0428, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 337, 'eta': 2.779, 'loss': 0.0005, 'lr': 0.0006, 'params': 281674, 'time_iter': 0.0409, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 338, 'eta': 2.7323, 'loss': 0.0005, 'lr': 0.0006, 'params': 281674, 'time_iter': 0.0342, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 339, 'eta': 2.6855, 'loss': 0.0005, 'lr': 0.0006, 'params': 281674, 'time_iter': 0.0332, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 339, 'loss': 6.363, 'lr': 0, 'params': 281674, 'time_iter': 0.0074, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 340, 'eta': 2.6394, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0375, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 341, 'eta': 2.593, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0347, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 342, 'eta': 2.5478, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0419, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 343, 'eta': 2.5023, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0394, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 344, 'eta': 2.4568, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0398, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 345, 'eta': 2.4121, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0444, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 346, 'eta': 2.3668, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0408, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 347, 'eta': 2.3215, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0401, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 348, 'eta': 2.2759, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0382, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 349, 'eta': 2.2309, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0417, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 350, 'eta': 2.1849, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0349, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 351, 'eta': 2.1394, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0381, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 352, 'eta': 2.0948, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0439, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 353, 'eta': 2.0501, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.044, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 354, 'eta': 2.0063, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0504, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 355, 'eta': 1.9616, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0434, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 356, 'eta': 1.9171, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0453, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 357, 'eta': 1.8723, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0431, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 358, 'eta': 1.8273, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0408, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 359, 'eta': 1.7824, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0417, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 359, 'loss': 6.3326, 'lr': 0, 'params': 281674, 'time_iter': 0.0052, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 360, 'eta': 1.7376, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0421, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 361, 'eta': 1.6927, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0416, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 362, 'eta': 1.6479, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0417, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 363, 'eta': 1.603, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0409, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 364, 'eta': 1.5582, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0423, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 365, 'eta': 1.5134, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0416, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 366, 'eta': 1.4687, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0414, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 367, 'eta': 1.4238, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0405, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 368, 'eta': 1.3794, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0457, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 369, 'eta': 1.3352, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0481, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 370, 'eta': 1.2902, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.038, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 371, 'eta': 1.2454, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0409, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 372, 'eta': 1.2007, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0412, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 373, 'eta': 1.156, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0405, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 374, 'eta': 1.1113, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.041, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 375, 'eta': 1.0662, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0351, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 376, 'eta': 1.0217, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0431, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 377, 'eta': 0.9768, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0365, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 378, 'eta': 0.9323, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0413, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 379, 'eta': 0.8878, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.044, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 379, 'loss': 6.3119, 'lr': 0, 'params': 281674, 'time_iter': 0.0096, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 380, 'eta': 0.8429, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0337, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 381, 'eta': 0.7985, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0442, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 382, 'eta': 0.7542, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0447, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 383, 'eta': 0.7096, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0396, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 384, 'eta': 0.6652, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0411, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 385, 'eta': 0.6207, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.041, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 386, 'eta': 0.5763, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0436, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 387, 'eta': 0.5318, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0382, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 388, 'eta': 0.4875, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0429, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 389, 'eta': 0.4431, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0419, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 390, 'eta': 0.3985, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0338, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 391, 'eta': 0.3541, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0392, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 392, 'eta': 0.3098, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0422, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 393, 'eta': 0.2657, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0511, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 394, 'eta': 0.2214, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0455, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 395, 'eta': 0.1772, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.047, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 396, 'eta': 0.1329, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0438, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 397, 'eta': 0.0886, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0495, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 398, 'eta': 0.0443, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0483, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 399, 'eta': 0.0, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0388, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 399, 'loss': 6.3015, 'lr': 0, 'params': 281674, 'time_iter': 0.0059, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# Task done, results saved in results/CCL1_GSE40240_eset
# 0
# {'epoch': 0, 'loss': 1.769, 'lr': 0, 'params': 281674, 'time_iter': 0.0069, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# {'epoch': 0, 'eta': 18.5063, 'loss': 1.1845, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0464, 'accuracy': 0.3636, 'precision': 0.2, 'recall': 0.25, 'f1': 0.2222, 'auc': 0.3036}
# End
# results/CCL1_GSE40240_eset/agg
# Results aggregated across runs saved in results/CCL1_GSE40240_eset/agg
# Visualization data stored at: Visuals/CCL1_GSE40240_eset_visuals.pt
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# 1
# True

# %% [markdown]
# # Retreive latent data for visualizations
#
# Look near the end for location of the visuals (Line like "Visualization data stored at: ")

# %%
import torch

visual_data = torch.load("Visuals/CCL1_GSE40240_eset_visuals.pt")

latent_data = visual_data['latent']
label_data = visual_data['truth']

# %%
from Visualization import Visualize

Visualize.visualize_PCA(latent_data, label_data)
Visualize.visualize_TSNE(latent_data, label_data)
# Out:
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
