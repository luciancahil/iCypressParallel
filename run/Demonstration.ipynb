# %%
# !python -V
# Out:
# Python 3.7.16

# %% [markdown]
# #Train Model

# %%
# !bash custom.sh GSE40240_eset GSE40240_patients CCL1 False NULL True
# Out:
# CCL1_GSE40240_eset
# Processing...
# CCL1_GSE40240_eset
# Done!
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/torch_geometric/graphgym/imports.py:14: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/torch_geometric/graphgym/logger.py:23: UserWarning: Please install 'pytorch_lightning' for using the GraphGym experiment manager via 'pip install pytorch_lightning'
#   warnings.warn("Please install 'pytorch_lightning' for using the GraphGym "
# WARNING:root:dataset.transductive changed to False for graph task.
# Load: 0.0288s, Before split: 0.0002217s, Split: 6.914e-05s, After split: 0.0004468s
# GNN(
#   (preprocess): Preprocess(
#     node_feature: dim_out=119
#     Total: dim_out=119
#   )
#   (pre_mp): GeneralMultiLayer(
#     (Layer_0): GeneralLayer(
#       (layer): Linear(
#         (model): Linear(in_features=119, out_features=137, bias=False)
#       )
#       (post_layer): Sequential(
#         (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): PReLU(num_parameters=1)
#       )
#     )
#     (Layer_1): GeneralLayer(
#       (layer): Linear(
#         (model): Linear(in_features=137, out_features=137, bias=False)
#       )
#       (post_layer): Sequential(
#         (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): PReLU(num_parameters=1)
#       )
#     )
#   )
#   (mp): GNNSkipStage(
#     (block0): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block1): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block2): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block3): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block4): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (block5): GNNSkipBlock(
#       (f): Sequential(
#         (0): GeneralLayer(
#           (layer): GeneralConv(
#             (model): GeneralConvLayer(137, 137)
#           )
#           (post_layer): Sequential(
#             (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (act): PReLU(num_parameters=1)
#     )
#   )
#   (post_mp): GNNGraphHead(
#     (layer_post_mp): MLP(
#       (model): Sequential(
#         (0): GeneralMultiLayer(
#           (Layer_0): GeneralLayer(
#             (layer): Linear(
#               (model): Linear(in_features=137, out_features=137, bias=False)
#             )
#             (post_layer): Sequential(
#               (0): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): PReLU(num_parameters=1)
#             )
#           )
#         )
#         (1): Linear(
#           (model): Linear(in_features=137, out_features=1, bias=True)
#         )
#       )
#     )
#   )
# )
# bn:
#   eps: 1e-05
#   mom: 0.1
# cfg_dest: config.yaml
# custom_metrics: []
# dataset:
#   augment_feature: []
#   augment_feature_dims: []
#   augment_feature_repr: position
#   augment_label:
#   augment_label_dims: 0
#   cache_load: False
#   cache_save: False
#   dir: ./datasets
#   edge_dim: 128
#   edge_encoder: False
#   edge_encoder_bn: True
#   edge_encoder_name: Bond
#   edge_message_ratio: 0.8
#   edge_negative_sampling_ratio: 1.0
#   edge_train_mode: all
#   encoder: True
#   encoder_bn: True
#   encoder_dim: 128
#   encoder_name: db
#   format: PyG
#   label_column: none
#   label_table: none
#   location: local
#   name: Custom,CCL1_GSE40240_eset,,
#   node_encoder: False
#   node_encoder_bn: True
#   node_encoder_name: Atom
#   remove_feature: False
#   resample_disjoint: False
#   resample_negative: False
#   shuffle_split: True
#   split: [0.8, 0.2]
#   split_mode: random
#   task: graph
#   task_type: classification
#   to_undirected: False
#   transductive: False
#   transform: none
#   tu_simple: True
# device: cpu
# example_arg: example
# example_group:
#   example_arg: example
# gnn:
#   act: prelu
#   agg: add
#   att_final_linear: False
#   att_final_linear_bn: False
#   att_heads: 1
#   batchnorm: True
#   clear_feature: True
#   dim_inner: 137
#   dropout: 0.0
#   flow: source_to_target
#   head: graph
#   keep_edge: 0.5
#   l2norm: True
#   layer_type: generalconv
#   layers_mp: 6
#   layers_post_mp: 2
#   layers_pre_mp: 2
#   msg_direction: single
#   normalize_adj: False
#   self_msg: concat
#   skip_every: 1
#   stage_type: skipsum
# gpu_mem: False
# mem:
#   inplace: False
# metric_agg: argmax
# metric_best: auto
# model:
#   edge_decoding: dot
#   graph_pooling: add
#   loss_fun: cross_entropy
#   match_upper: True
#   size_average: mean
#   thresh: 0.5
#   type: gnn
# num_threads: 6
# num_workers: 0
# optim:
#   base_lr: 0.01
#   lr_decay: 0.1
#   max_epoch: 400
#   momentum: 0.9
#   optimizer: adam
#   scheduler: cos
#   steps: [30, 60, 90]
#   weight_decay: 0.0005
# out_dir: results/CCL1_GSE40240_eset
# print: both
# round: 4
# run_dir: results/CCL1_GSE40240_eset/0
# seed: 1
# share:
#   dim_in: 119
#   dim_out: 1
#   num_splits: 2
# tensorboard_agg: True
# tensorboard_each_run: False
# train:
#   auto_resume: False
#   batch_size: 80
#   ckpt_clean: True
#   ckpt_period: 100
#   enable_ckpt: True
#   epoch_resume: -1
#   eval_period: 20
#   iter_per_epoch: 32
#   mode: standard
#   neighbor_sizes: [20, 15, 10, 5]
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
#   skip_train_eval: False
#   walk_length: 4
# val:
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
# view_emb: False
# Num parameters: 281674
# Start from epoch 0
# train: {'epoch': 0, 'eta': 21.4137, 'loss': 1.1845, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0537, 'accuracy': 0.3636, 'precision': 0.2, 'recall': 0.25, 'f1': 0.2222, 'auc': 0.3036}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 0, 'loss': 1.769, 'lr': 0, 'params': 281674, 'time_iter': 0.0066, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 1, 'eta': 20.0608, 'loss': 0.9891, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0471, 'accuracy': 0.7273, 'precision': 0.5833, 'recall': 0.875, 'f1': 0.7, 'auc': 0.8125}
# train: {'epoch': 2, 'eta': 19.6661, 'loss': 1.0769, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0478, 'accuracy': 0.7727, 'precision': 0.6667, 'recall': 0.75, 'f1': 0.7059, 'auc': 0.7411}
# train: {'epoch': 3, 'eta': 18.9773, 'loss': 0.1538, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0431, 'accuracy': 0.9091, 'precision': 0.875, 'recall': 0.875, 'f1': 0.875, 'auc': 0.9911}
# train: {'epoch': 4, 'eta': 18.499, 'loss': 0.0818, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0425, 'accuracy': 0.9545, 'precision': 0.8889, 'recall': 1.0, 'f1': 0.9412, 'auc': 1.0}
# train: {'epoch': 5, 'eta': 18.1681, 'loss': 0.0326, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0425, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 6, 'eta': 17.5774, 'loss': 0.0213, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0364, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 7, 'eta': 17.1538, 'loss': 0.0185, 'lr': 0.01, 'params': 281674, 'time_iter': 0.037, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 8, 'eta': 17.022, 'loss': 0.0097, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0417, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 9, 'eta': 16.7338, 'loss': 0.0054, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0373, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 10, 'eta': 16.8906, 'loss': 0.0037, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0486, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 11, 'eta': 16.7791, 'loss': 0.0029, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0413, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 12, 'eta': 16.5842, 'loss': 0.0024, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0382, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 13, 'eta': 16.2794, 'loss': 0.0021, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0334, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 14, 'eta': 16.1092, 'loss': 0.0018, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0372, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 15, 'eta': 15.9853, 'loss': 0.0015, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0384, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 16, 'eta': 15.8352, 'loss': 0.0014, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0368, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 17, 'eta': 15.8816, 'loss': 0.0012, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0455, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 18, 'eta': 15.7764, 'loss': 0.0011, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0384, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 19, 'eta': 16.0274, 'loss': 0.001, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0568, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 19, 'loss': 3.5808, 'lr': 0, 'params': 281674, 'time_iter': 0.0068, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 20, 'eta': 16.0253, 'loss': 0.0009, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0444, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 21, 'eta': 16.0229, 'loss': 0.0008, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0446, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 22, 'eta': 15.9964, 'loss': 0.0008, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0434, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 23, 'eta': 15.953, 'loss': 0.0007, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0424, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 24, 'eta': 15.898, 'loss': 0.0007, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0416, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 25, 'eta': 15.9036, 'loss': 0.0007, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0457, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 26, 'eta': 15.8537, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.042, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 27, 'eta': 15.8475, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0452, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 28, 'eta': 15.8373, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0451, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 29, 'eta': 15.8563, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0477, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 30, 'eta': 15.7995, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0417, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 31, 'eta': 15.9987, 'loss': 0.0006, 'lr': 0.0099, 'params': 281674, 'time_iter': 0.0639, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 32, 'eta': 15.933, 'loss': 0.0006, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0415, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 33, 'eta': 15.9414, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0482, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 34, 'eta': 15.8776, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0416, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 35, 'eta': 15.8401, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0441, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 36, 'eta': 15.8462, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0486, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 37, 'eta': 15.8133, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0448, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 38, 'eta': 15.8237, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0495, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 39, 'eta': 15.848, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0514, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 39, 'loss': 6.7528, 'lr': 0, 'params': 281674, 'time_iter': 0.0054, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 40, 'eta': 15.8537, 'loss': 0.0005, 'lr': 0.0098, 'params': 281674, 'time_iter': 0.0497, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 41, 'eta': 15.9116, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0561, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 42, 'eta': 16.0052, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0611, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 43, 'eta': 16.0832, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.06, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 44, 'eta': 16.2604, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0734, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 45, 'eta': 16.1941, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0431, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 46, 'eta': 16.1338, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0438, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 47, 'eta': 16.0225, 'loss': 0.0005, 'lr': 0.0097, 'params': 281674, 'time_iter': 0.0368, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 48, 'eta': 15.9184, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0373, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 49, 'eta': 15.8257, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0386, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 50, 'eta': 15.7966, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0476, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 51, 'eta': 15.7666, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0475, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 52, 'eta': 15.7387, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.048, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 53, 'eta': 15.6602, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0402, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 54, 'eta': 15.5744, 'loss': 0.0004, 'lr': 0.0096, 'params': 281674, 'time_iter': 0.0388, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 55, 'eta': 15.4369, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0301, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 56, 'eta': 15.3402, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0363, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 57, 'eta': 15.3811, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0593, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 58, 'eta': 15.3689, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0506, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 59, 'eta': 15.252, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0324, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 59, 'loss': 7.7289, 'lr': 0, 'params': 281674, 'time_iter': 0.0119, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 60, 'eta': 15.1724, 'loss': 0.0004, 'lr': 0.0095, 'params': 281674, 'time_iter': 0.0386, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 61, 'eta': 15.0908, 'loss': 0.0004, 'lr': 0.0094, 'params': 281674, 'time_iter': 0.038, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 62, 'eta': 15.0499, 'loss': 0.0004, 'lr': 0.0094, 'params': 281674, 'time_iter': 0.0453, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 63, 'eta': 14.9685, 'loss': 0.0004, 'lr': 0.0094, 'params': 281674, 'time_iter': 0.0377, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 64, 'eta': 14.8962, 'loss': 0.0004, 'lr': 0.0094, 'params': 281674, 'time_iter': 0.0391, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 65, 'eta': 14.8875, 'loss': 0.0004, 'lr': 0.0094, 'params': 281674, 'time_iter': 0.0515, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 66, 'eta': 14.9096, 'loss': 0.0004, 'lr': 0.0093, 'params': 281674, 'time_iter': 0.058, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 67, 'eta': 14.8725, 'loss': 0.0004, 'lr': 0.0093, 'params': 281674, 'time_iter': 0.0463, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 68, 'eta': 14.833, 'loss': 0.0004, 'lr': 0.0093, 'params': 281674, 'time_iter': 0.0459, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 69, 'eta': 14.8454, 'loss': 0.0004, 'lr': 0.0093, 'params': 281674, 'time_iter': 0.0569, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 70, 'eta': 14.7714, 'loss': 0.0004, 'lr': 0.0093, 'params': 281674, 'time_iter': 0.0387, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 71, 'eta': 14.7379, 'loss': 0.0004, 'lr': 0.0092, 'params': 281674, 'time_iter': 0.0474, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 72, 'eta': 14.6856, 'loss': 0.0004, 'lr': 0.0092, 'params': 281674, 'time_iter': 0.0433, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 73, 'eta': 14.6939, 'loss': 0.0004, 'lr': 0.0092, 'params': 281674, 'time_iter': 0.057, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 74, 'eta': 14.6527, 'loss': 0.0004, 'lr': 0.0092, 'params': 281674, 'time_iter': 0.046, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 75, 'eta': 14.6111, 'loss': 0.0004, 'lr': 0.0092, 'params': 281674, 'time_iter': 0.0459, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 76, 'eta': 14.5568, 'loss': 0.0004, 'lr': 0.0091, 'params': 281674, 'time_iter': 0.0429, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 77, 'eta': 14.5226, 'loss': 0.0004, 'lr': 0.0091, 'params': 281674, 'time_iter': 0.0477, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 78, 'eta': 14.4525, 'loss': 0.0004, 'lr': 0.0091, 'params': 281674, 'time_iter': 0.039, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 79, 'eta': 14.5137, 'loss': 0.0004, 'lr': 0.0091, 'params': 281674, 'time_iter': 0.0716, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 79, 'loss': 7.6715, 'lr': 0, 'params': 281674, 'time_iter': 0.0379, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 80, 'eta': 14.6022, 'loss': 0.0004, 'lr': 0.009, 'params': 281674, 'time_iter': 0.0793, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 81, 'eta': 14.6045, 'loss': 0.0004, 'lr': 0.009, 'params': 281674, 'time_iter': 0.0582, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 82, 'eta': 14.5897, 'loss': 0.0004, 'lr': 0.009, 'params': 281674, 'time_iter': 0.0541, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 83, 'eta': 14.5602, 'loss': 0.0004, 'lr': 0.009, 'params': 281674, 'time_iter': 0.0504, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 84, 'eta': 14.5267, 'loss': 0.0004, 'lr': 0.009, 'params': 281674, 'time_iter': 0.0495, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 85, 'eta': 14.4929, 'loss': 0.0004, 'lr': 0.0089, 'params': 281674, 'time_iter': 0.0495, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 86, 'eta': 14.4535, 'loss': 0.0004, 'lr': 0.0089, 'params': 281674, 'time_iter': 0.0481, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 87, 'eta': 14.4192, 'loss': 0.0004, 'lr': 0.0089, 'params': 281674, 'time_iter': 0.0495, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 88, 'eta': 14.3863, 'loss': 0.0004, 'lr': 0.0089, 'params': 281674, 'time_iter': 0.05, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 89, 'eta': 14.3516, 'loss': 0.0004, 'lr': 0.0088, 'params': 281674, 'time_iter': 0.0496, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 90, 'eta': 14.3099, 'loss': 0.0004, 'lr': 0.0088, 'params': 281674, 'time_iter': 0.0477, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 91, 'eta': 14.2711, 'loss': 0.0004, 'lr': 0.0088, 'params': 281674, 'time_iter': 0.0485, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 92, 'eta': 14.2332, 'loss': 0.0004, 'lr': 0.0088, 'params': 281674, 'time_iter': 0.0489, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 93, 'eta': 14.1953, 'loss': 0.0004, 'lr': 0.0087, 'params': 281674, 'time_iter': 0.049, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 94, 'eta': 14.2662, 'loss': 0.0004, 'lr': 0.0087, 'params': 281674, 'time_iter': 0.0829, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 95, 'eta': 14.2743, 'loss': 0.0004, 'lr': 0.0087, 'params': 281674, 'time_iter': 0.0641, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 96, 'eta': 14.3097, 'loss': 0.0004, 'lr': 0.0086, 'params': 281674, 'time_iter': 0.0733, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 97, 'eta': 14.4033, 'loss': 0.0004, 'lr': 0.0086, 'params': 281674, 'time_iter': 0.0929, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 98, 'eta': 14.4, 'loss': 0.0004, 'lr': 0.0086, 'params': 281674, 'time_iter': 0.0623, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 99, 'eta': 14.3983, 'loss': 0.0004, 'lr': 0.0086, 'params': 281674, 'time_iter': 0.0632, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 99, 'loss': 7.403, 'lr': 0, 'params': 281674, 'time_iter': 0.0233, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 100, 'eta': 14.487, 'loss': 0.0004, 'lr': 0.0085, 'params': 281674, 'time_iter': 0.0942, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 101, 'eta': 14.4317, 'loss': 0.0004, 'lr': 0.0085, 'params': 281674, 'time_iter': 0.0461, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 102, 'eta': 14.3737, 'loss': 0.0004, 'lr': 0.0085, 'params': 281674, 'time_iter': 0.0451, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 103, 'eta': 14.3206, 'loss': 0.0004, 'lr': 0.0085, 'params': 281674, 'time_iter': 0.0467, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 104, 'eta': 14.2741, 'loss': 0.0004, 'lr': 0.0084, 'params': 281674, 'time_iter': 0.0491, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 105, 'eta': 14.2197, 'loss': 0.0004, 'lr': 0.0084, 'params': 281674, 'time_iter': 0.0462, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 106, 'eta': 14.1629, 'loss': 0.0004, 'lr': 0.0084, 'params': 281674, 'time_iter': 0.0453, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 107, 'eta': 14.1232, 'loss': 0.0004, 'lr': 0.0083, 'params': 281674, 'time_iter': 0.0515, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 108, 'eta': 14.0709, 'loss': 0.0004, 'lr': 0.0083, 'params': 281674, 'time_iter': 0.0469, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 109, 'eta': 14.0299, 'loss': 0.0004, 'lr': 0.0083, 'params': 281674, 'time_iter': 0.0511, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 110, 'eta': 13.9802, 'loss': 0.0004, 'lr': 0.0082, 'params': 281674, 'time_iter': 0.0479, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 111, 'eta': 13.939, 'loss': 0.0004, 'lr': 0.0082, 'params': 281674, 'time_iter': 0.0511, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 112, 'eta': 13.9256, 'loss': 0.0004, 'lr': 0.0082, 'params': 281674, 'time_iter': 0.0622, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 113, 'eta': 13.8913, 'loss': 0.0004, 'lr': 0.0082, 'params': 281674, 'time_iter': 0.0542, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 114, 'eta': 13.8427, 'loss': 0.0004, 'lr': 0.0081, 'params': 281674, 'time_iter': 0.0486, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 115, 'eta': 13.9107, 'loss': 0.0004, 'lr': 0.0081, 'params': 281674, 'time_iter': 0.0962, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 116, 'eta': 13.8688, 'loss': 0.0004, 'lr': 0.0081, 'params': 281674, 'time_iter': 0.0519, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 117, 'eta': 13.8358, 'loss': 0.0004, 'lr': 0.008, 'params': 281674, 'time_iter': 0.0557, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 118, 'eta': 13.7952, 'loss': 0.0004, 'lr': 0.008, 'params': 281674, 'time_iter': 0.0526, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 119, 'eta': 13.7517, 'loss': 0.0004, 'lr': 0.008, 'params': 281674, 'time_iter': 0.0515, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 119, 'loss': 7.2298, 'lr': 0, 'params': 281674, 'time_iter': 0.0073, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 120, 'eta': 13.7087, 'loss': 0.0004, 'lr': 0.0079, 'params': 281674, 'time_iter': 0.0518, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 121, 'eta': 13.6669, 'loss': 0.0004, 'lr': 0.0079, 'params': 281674, 'time_iter': 0.0524, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 122, 'eta': 13.6271, 'loss': 0.0004, 'lr': 0.0079, 'params': 281674, 'time_iter': 0.0533, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 123, 'eta': 13.5827, 'loss': 0.0004, 'lr': 0.0078, 'params': 281674, 'time_iter': 0.0513, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 124, 'eta': 13.5405, 'loss': 0.0004, 'lr': 0.0078, 'params': 281674, 'time_iter': 0.0524, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 125, 'eta': 13.5037, 'loss': 0.0004, 'lr': 0.0078, 'params': 281674, 'time_iter': 0.0549, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 126, 'eta': 13.4603, 'loss': 0.0004, 'lr': 0.0077, 'params': 281674, 'time_iter': 0.0521, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 127, 'eta': 13.4147, 'loss': 0.0004, 'lr': 0.0077, 'params': 281674, 'time_iter': 0.051, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 128, 'eta': 13.3687, 'loss': 0.0004, 'lr': 0.0077, 'params': 281674, 'time_iter': 0.0509, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 129, 'eta': 13.3229, 'loss': 0.0004, 'lr': 0.0076, 'params': 281674, 'time_iter': 0.051, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 130, 'eta': 13.2845, 'loss': 0.0004, 'lr': 0.0076, 'params': 281674, 'time_iter': 0.0547, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 131, 'eta': 13.2384, 'loss': 0.0004, 'lr': 0.0076, 'params': 281674, 'time_iter': 0.051, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 132, 'eta': 13.1928, 'loss': 0.0004, 'lr': 0.0075, 'params': 281674, 'time_iter': 0.0513, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 133, 'eta': 13.2116, 'loss': 0.0004, 'lr': 0.0075, 'params': 281674, 'time_iter': 0.0838, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 134, 'eta': 13.2118, 'loss': 0.0004, 'lr': 0.0075, 'params': 281674, 'time_iter': 0.0751, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 135, 'eta': 13.1675, 'loss': 0.0004, 'lr': 0.0074, 'params': 281674, 'time_iter': 0.0527, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 136, 'eta': 13.1211, 'loss': 0.0004, 'lr': 0.0074, 'params': 281674, 'time_iter': 0.0516, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 137, 'eta': 13.0665, 'loss': 0.0004, 'lr': 0.0074, 'params': 281674, 'time_iter': 0.0475, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 138, 'eta': 13.0061, 'loss': 0.0004, 'lr': 0.0073, 'params': 281674, 'time_iter': 0.0442, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 139, 'eta': 12.941, 'loss': 0.0004, 'lr': 0.0073, 'params': 281674, 'time_iter': 0.0416, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 139, 'loss': 7.108, 'lr': 0, 'params': 281674, 'time_iter': 0.0078, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 140, 'eta': 12.8832, 'loss': 0.0004, 'lr': 0.0073, 'params': 281674, 'time_iter': 0.0454, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 141, 'eta': 12.8124, 'loss': 0.0004, 'lr': 0.0072, 'params': 281674, 'time_iter': 0.0382, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 142, 'eta': 12.7502, 'loss': 0.0004, 'lr': 0.0072, 'params': 281674, 'time_iter': 0.0426, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 143, 'eta': 12.6914, 'loss': 0.0004, 'lr': 0.0072, 'params': 281674, 'time_iter': 0.0444, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 144, 'eta': 12.6271, 'loss': 0.0004, 'lr': 0.0071, 'params': 281674, 'time_iter': 0.0412, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 145, 'eta': 12.6052, 'loss': 0.0004, 'lr': 0.0071, 'params': 281674, 'time_iter': 0.0654, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 146, 'eta': 12.5427, 'loss': 0.0004, 'lr': 0.0071, 'params': 281674, 'time_iter': 0.0422, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 147, 'eta': 12.4841, 'loss': 0.0004, 'lr': 0.007, 'params': 281674, 'time_iter': 0.0443, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 148, 'eta': 12.4134, 'loss': 0.0004, 'lr': 0.007, 'params': 281674, 'time_iter': 0.037, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 149, 'eta': 12.3652, 'loss': 0.0005, 'lr': 0.0069, 'params': 281674, 'time_iter': 0.0502, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 150, 'eta': 12.3107, 'loss': 0.0005, 'lr': 0.0069, 'params': 281674, 'time_iter': 0.0464, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 151, 'eta': 12.2412, 'loss': 0.0005, 'lr': 0.0069, 'params': 281674, 'time_iter': 0.0371, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 152, 'eta': 12.1841, 'loss': 0.0005, 'lr': 0.0068, 'params': 281674, 'time_iter': 0.0445, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 153, 'eta': 12.133, 'loss': 0.0005, 'lr': 0.0068, 'params': 281674, 'time_iter': 0.0482, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 154, 'eta': 12.0721, 'loss': 0.0005, 'lr': 0.0068, 'params': 281674, 'time_iter': 0.042, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 155, 'eta': 12.0131, 'loss': 0.0005, 'lr': 0.0067, 'params': 281674, 'time_iter': 0.0431, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 156, 'eta': 11.9588, 'loss': 0.0005, 'lr': 0.0067, 'params': 281674, 'time_iter': 0.0459, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 157, 'eta': 11.909, 'loss': 0.0005, 'lr': 0.0067, 'params': 281674, 'time_iter': 0.0488, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 158, 'eta': 11.8524, 'loss': 0.0005, 'lr': 0.0066, 'params': 281674, 'time_iter': 0.0443, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 159, 'eta': 11.7961, 'loss': 0.0005, 'lr': 0.0066, 'params': 281674, 'time_iter': 0.0445, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 159, 'loss': 7.0053, 'lr': 0, 'params': 281674, 'time_iter': 0.0056, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 160, 'eta': 11.7379, 'loss': 0.0005, 'lr': 0.0065, 'params': 281674, 'time_iter': 0.043, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 161, 'eta': 11.6797, 'loss': 0.0005, 'lr': 0.0065, 'params': 281674, 'time_iter': 0.0429, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 162, 'eta': 11.6231, 'loss': 0.0005, 'lr': 0.0065, 'params': 281674, 'time_iter': 0.0439, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 163, 'eta': 11.5658, 'loss': 0.0005, 'lr': 0.0064, 'params': 281674, 'time_iter': 0.0433, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 164, 'eta': 11.5067, 'loss': 0.0005, 'lr': 0.0064, 'params': 281674, 'time_iter': 0.0419, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 165, 'eta': 11.453, 'loss': 0.0005, 'lr': 0.0064, 'params': 281674, 'time_iter': 0.0456, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 166, 'eta': 11.3872, 'loss': 0.0005, 'lr': 0.0063, 'params': 281674, 'time_iter': 0.0369, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 167, 'eta': 11.3322, 'loss': 0.0005, 'lr': 0.0063, 'params': 281674, 'time_iter': 0.0444, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 168, 'eta': 11.2773, 'loss': 0.0005, 'lr': 0.0062, 'params': 281674, 'time_iter': 0.0445, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 169, 'eta': 11.2227, 'loss': 0.0005, 'lr': 0.0062, 'params': 281674, 'time_iter': 0.0445, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 170, 'eta': 11.1636, 'loss': 0.0005, 'lr': 0.0062, 'params': 281674, 'time_iter': 0.0411, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 171, 'eta': 11.0963, 'loss': 0.0005, 'lr': 0.0061, 'params': 281674, 'time_iter': 0.0348, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 172, 'eta': 11.032, 'loss': 0.0005, 'lr': 0.0061, 'params': 281674, 'time_iter': 0.0368, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 173, 'eta': 10.987, 'loss': 0.0005, 'lr': 0.0061, 'params': 281674, 'time_iter': 0.0513, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 174, 'eta': 10.9271, 'loss': 0.0005, 'lr': 0.006, 'params': 281674, 'time_iter': 0.0398, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 175, 'eta': 10.871, 'loss': 0.0005, 'lr': 0.006, 'params': 281674, 'time_iter': 0.0427, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 176, 'eta': 10.8099, 'loss': 0.0005, 'lr': 0.0059, 'params': 281674, 'time_iter': 0.0386, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 177, 'eta': 10.7448, 'loss': 0.0005, 'lr': 0.0059, 'params': 281674, 'time_iter': 0.0351, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 178, 'eta': 10.6795, 'loss': 0.0005, 'lr': 0.0059, 'params': 281674, 'time_iter': 0.0347, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 179, 'eta': 10.6172, 'loss': 0.0005, 'lr': 0.0058, 'params': 281674, 'time_iter': 0.0369, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 179, 'loss': 6.9166, 'lr': 0, 'params': 281674, 'time_iter': 0.0052, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 180, 'eta': 10.5563, 'loss': 0.0005, 'lr': 0.0058, 'params': 281674, 'time_iter': 0.0378, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 181, 'eta': 10.4944, 'loss': 0.0005, 'lr': 0.0057, 'params': 281674, 'time_iter': 0.0368, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 182, 'eta': 10.451, 'loss': 0.0005, 'lr': 0.0057, 'params': 281674, 'time_iter': 0.0522, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 183, 'eta': 10.3946, 'loss': 0.0005, 'lr': 0.0057, 'params': 281674, 'time_iter': 0.0411, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 184, 'eta': 10.3381, 'loss': 0.0005, 'lr': 0.0056, 'params': 281674, 'time_iter': 0.0409, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 185, 'eta': 10.2697, 'loss': 0.0005, 'lr': 0.0056, 'params': 281674, 'time_iter': 0.0305, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 186, 'eta': 10.2226, 'loss': 0.0005, 'lr': 0.0055, 'params': 281674, 'time_iter': 0.0488, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 187, 'eta': 10.1663, 'loss': 0.0005, 'lr': 0.0055, 'params': 281674, 'time_iter': 0.0406, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 188, 'eta': 10.1277, 'loss': 0.0005, 'lr': 0.0055, 'params': 281674, 'time_iter': 0.0563, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 189, 'eta': 10.0671, 'loss': 0.0005, 'lr': 0.0054, 'params': 281674, 'time_iter': 0.0365, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 190, 'eta': 10.0076, 'loss': 0.0005, 'lr': 0.0054, 'params': 281674, 'time_iter': 0.0374, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 191, 'eta': 9.949, 'loss': 0.0005, 'lr': 0.0054, 'params': 281674, 'time_iter': 0.0379, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 192, 'eta': 9.8868, 'loss': 0.0005, 'lr': 0.0053, 'params': 281674, 'time_iter': 0.0344, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 193, 'eta': 9.8382, 'loss': 0.0005, 'lr': 0.0053, 'params': 281674, 'time_iter': 0.0469, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 194, 'eta': 9.7798, 'loss': 0.0005, 'lr': 0.0052, 'params': 281674, 'time_iter': 0.0377, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 195, 'eta': 9.7186, 'loss': 0.0005, 'lr': 0.0052, 'params': 281674, 'time_iter': 0.0347, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 196, 'eta': 9.6589, 'loss': 0.0005, 'lr': 0.0052, 'params': 281674, 'time_iter': 0.0359, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 197, 'eta': 9.5993, 'loss': 0.0005, 'lr': 0.0051, 'params': 281674, 'time_iter': 0.0358, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 198, 'eta': 9.5422, 'loss': 0.0005, 'lr': 0.0051, 'params': 281674, 'time_iter': 0.038, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 199, 'eta': 9.5082, 'loss': 0.0005, 'lr': 0.005, 'params': 281674, 'time_iter': 0.061, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# train: {'epoch': 327, 'eta': 3.4501, 'loss': 0.0005, 'lr': 0.0008, 'params': 281674, 'time_iter': 0.0394, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 328, 'eta': 3.4022, 'loss': 0.0005, 'lr': 0.0008, 'params': 281674, 'time_iter': 0.0479, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 329, 'eta': 3.3532, 'loss': 0.0005, 'lr': 0.0008, 'params': 281674, 'time_iter': 0.0428, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 330, 'eta': 3.3048, 'loss': 0.0005, 'lr': 0.0007, 'params': 281674, 'time_iter': 0.0453, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 331, 'eta': 3.256, 'loss': 0.0005, 'lr': 0.0007, 'params': 281674, 'time_iter': 0.0435, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 332, 'eta': 3.2076, 'loss': 0.0005, 'lr': 0.0007, 'params': 281674, 'time_iter': 0.0457, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 333, 'eta': 3.1576, 'loss': 0.0005, 'lr': 0.0007, 'params': 281674, 'time_iter': 0.0367, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 334, 'eta': 3.1084, 'loss': 0.0005, 'lr': 0.0007, 'params': 281674, 'time_iter': 0.0408, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 335, 'eta': 3.0593, 'loss': 0.0005, 'lr': 0.0006, 'params': 281674, 'time_iter': 0.0413, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 336, 'eta': 3.0085, 'loss': 0.0005, 'lr': 0.0006, 'params': 281674, 'time_iter': 0.0321, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 337, 'eta': 2.9603, 'loss': 0.0005, 'lr': 0.0006, 'params': 281674, 'time_iter': 0.0451, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 338, 'eta': 2.9109, 'loss': 0.0005, 'lr': 0.0006, 'params': 281674, 'time_iter': 0.0387, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 339, 'eta': 2.8622, 'loss': 0.0005, 'lr': 0.0006, 'params': 281674, 'time_iter': 0.0422, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 339, 'loss': 6.363, 'lr': 0, 'params': 281674, 'time_iter': 0.0089, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 340, 'eta': 2.8153, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0521, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 341, 'eta': 2.7658, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0372, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 342, 'eta': 2.7154, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0317, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 343, 'eta': 2.6679, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0484, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 344, 'eta': 2.6183, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0349, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 345, 'eta': 2.5711, 'loss': 0.0005, 'lr': 0.0005, 'params': 281674, 'time_iter': 0.0501, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 346, 'eta': 2.5222, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0392, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 347, 'eta': 2.4738, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0426, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 348, 'eta': 2.4259, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0449, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 349, 'eta': 2.3771, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0391, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 350, 'eta': 2.3285, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0398, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 351, 'eta': 2.281, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0479, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 352, 'eta': 2.2328, 'loss': 0.0005, 'lr': 0.0004, 'params': 281674, 'time_iter': 0.0421, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 353, 'eta': 2.1843, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0403, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 354, 'eta': 2.1353, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0351, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 355, 'eta': 2.086, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0325, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 356, 'eta': 2.0382, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0446, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 357, 'eta': 1.9903, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0429, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 358, 'eta': 1.9415, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0347, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 359, 'eta': 1.8935, 'loss': 0.0005, 'lr': 0.0003, 'params': 281674, 'time_iter': 0.0421, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 359, 'loss': 6.3326, 'lr': 0, 'params': 281674, 'time_iter': 0.0052, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 360, 'eta': 1.8447, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0335, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 361, 'eta': 1.7975, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.048, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 362, 'eta': 1.7497, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0425, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 363, 'eta': 1.7018, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0413, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 364, 'eta': 1.6537, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0386, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 365, 'eta': 1.605, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0314, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 366, 'eta': 1.5568, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0364, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 367, 'eta': 1.5087, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0362, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 368, 'eta': 1.4608, 'loss': 0.0005, 'lr': 0.0002, 'params': 281674, 'time_iter': 0.0382, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 369, 'eta': 1.4125, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0331, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 370, 'eta': 1.3645, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0356, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 371, 'eta': 1.3164, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0332, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 372, 'eta': 1.2685, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0342, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 373, 'eta': 1.2212, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0421, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 374, 'eta': 1.1733, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0342, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 375, 'eta': 1.1256, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0338, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 376, 'eta': 1.0783, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0401, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 377, 'eta': 1.0309, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0395, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 378, 'eta': 0.9835, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0365, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 379, 'eta': 0.936, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0338, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 379, 'loss': 6.3119, 'lr': 0, 'params': 281674, 'time_iter': 0.0062, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# train: {'epoch': 380, 'eta': 0.8885, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0338, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 381, 'eta': 0.8414, 'loss': 0.0005, 'lr': 0.0001, 'params': 281674, 'time_iter': 0.0387, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 382, 'eta': 0.7942, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0364, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 383, 'eta': 0.7469, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0339, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 384, 'eta': 0.6998, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0345, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 385, 'eta': 0.6528, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0377, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 386, 'eta': 0.6059, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0382, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 387, 'eta': 0.5595, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0531, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 388, 'eta': 0.5128, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0443, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 389, 'eta': 0.4661, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0419, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 390, 'eta': 0.4192, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0333, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 391, 'eta': 0.3723, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0311, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 392, 'eta': 0.3256, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0366, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 393, 'eta': 0.2788, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0334, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 394, 'eta': 0.2324, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0477, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 395, 'eta': 0.1858, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0403, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 396, 'eta': 0.1393, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.039, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 397, 'eta': 0.0928, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.032, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 398, 'eta': 0.0464, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.0342, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# train: {'epoch': 399, 'eta': 0.0, 'loss': 0.0005, 'lr': 0.0, 'params': 281674, 'time_iter': 0.042, 'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'auc': 1.0}
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 399, 'loss': 6.3015, 'lr': 0, 'params': 281674, 'time_iter': 0.0057, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# Task done, results saved in results/CCL1_GSE40240_eset
# 0
# {'epoch': 0, 'loss': 1.769, 'lr': 0, 'params': 281674, 'time_iter': 0.0066, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.0}
# {'epoch': 0, 'eta': 21.4137, 'loss': 1.1845, 'lr': 0.01, 'params': 281674, 'time_iter': 0.0537, 'accuracy': 0.3636, 'precision': 0.2, 'recall': 0.25, 'f1': 0.2222, 'auc': 0.3036}
# End
# results/CCL1_GSE40240_eset/agg
# Results aggregated across runs saved in results/CCL1_GSE40240_eset/agg
# Visualization data stored at: Visuals/CCL1_GSE40240_eset_visuals.pt
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# 1
# True

# %%
# Retreive latent data for visualizations

Look near the end for location of the visuals (Line like "Visualization data stored at: ")

# %%
import torch

visual_data = torch.load("Visuals/CCL1_GSE40240_eset_visuals.pt")

latent_data = visual_data['latent']
label_data = visual_data['truth']

# %%
from Visualization import Visualize

Visualize.visualize_PCA(latent_data, label_data)
Visualize.visualize_TSNE(latent_data, label_data)
# Out:
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /home/royhe62/anaconda3/envs/cypress-env/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
